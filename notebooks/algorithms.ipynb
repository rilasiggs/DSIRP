# %% [markdown]
# # Algorithms

# %% [markdown]
# [Click here to run this chapter on Colab](https://colab.research.google.com/github/AllenDowney/DSIRP/blob/main/notebooks/algorithms.ipynb)

# %% [markdown]
# ## Searching for anagrams
#
# In this notebook we'll implement algorithms for two tasks:
#
# * Testing a pair of words to see if they are anagrams of each other, that is, if you can rearrange the letters in one word to spell the other.
#
# * Searching a list of words for all pairs that are anagrams of each other.
#
# There is a point to these examples, which I will explain at the end.

# %% [markdown]
# **Exercise 1:** Write a function that takes two words and returns `True` if they are anagrams. Test your function with the examples below.

# %%
def is_anagram(word1, word2):
    if(sorted(word1)==sorted(word2)):
        return True
    else:
        return False

# %%
is_anagram('tachymetric', 'mccarthyite') # True
# Out:
# True

# %%
is_anagram('post', 'top') # False, letter not present
# Out:
# ['o', 'p', 's', 't'] ['o', 'p', 't']
# False

# %%
is_anagram('pott', 'top') # False, letter present but not enough copies
# Out:
# ['o', 'p', 't', 't'] ['o', 'p', 't']
# False

# %%
is_anagram('top', 'post') # False, letters left over at the end
# Out:
# ['o', 'p', 't'] ['o', 'p', 's', 't']
# False

# %%
is_anagram('topss', 'postt') # False
# Out:
# ['o', 'p', 's', 's', 't'] ['o', 'p', 's', 't', 't']
# False

# %% [markdown]
# **Exercise 2:** Use `timeit` to see how fast your function is for these examples:

# %%
# %timeit is_anagram('tops', 'spot')
# Out:
# 1.12 µs ± 57.7 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit is_anagram('tachymetric', 'mccarthyite')

# %% [markdown]
# How can we compare algorithms running on different computers?

# %% [markdown]
# ## Searching for anagram pairs

# %% [markdown]
# **Exercise 3:** Write a function that takes a word list and returns a list of all anagram pairs.

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

# %%
def all_anagram_pairs(word_list):
    for word in word_list:
        for word2 in word_list:
            if(sorted(word) == sorted(word2)) and word != word2:
                print(word, word2)
    return

# %%
all_anagram_pairs(short_word_list)
# Out:
# proudest sprouted
# stop pots
# stop tops
# pots stop
# pots tops
# tops stop
# tops pots
# sprouted proudest

# %% [markdown]
# The following cell downloads a file containing a list of English words.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)
    
download('https://github.com/AllenDowney/DSIRP/raw/main/american-english')

# %% [markdown]
# The following function reads a file and returns a set of words (I used a set because after we convert words to lower case, there are some repeats.)

# %%
def read_words(filename):
    """Read lines from a file and split them into words."""
    res = set()
    for line in open(filename):
        for word in line.split():
            res.add(word.strip().lower())
    return res

# %%
word_list = read_words('american-english')
len(word_list)
# Out:
# 100781

# %% [markdown]
# **Exercise 4:** Loop through the word list and print all words that are anagrams of `stop`.

# %%
word_list = read_words('american-english')
for word in word_list:
    if sorted(word) == sorted("stop"):
        print(word)
# Out:
# post
# opts
# spot
# tops
# pots
# stop

# %% [markdown]
# Now run `all_anagram_pairs` with the full `word_list`:

# %%
all_anagram_pairs(word_list)

# %% [markdown]
# **Exercise 5:** While that's running, let's estimate how long it's going to take.

# %%
# %timeit all_anagram_pairs(word_list)

# %% [markdown]
# ## A better algorithm
#
# **Exercise 6:** Write a better algorithm! Hint: make a dictionary. How much faster is your algorithm?

# %%
def all_anagram_list(set_of_str):
    dictionary = {}
    return_list = []
    for word in set_of_str:
        sorted_word = ''.join(sorted(word))
        if sorted_word not in dictionary:
            dictionary[sorted_word] = [word]
        else:
            dictionary[sorted_word].append(word)
    
    #remove words with no anagrams
    for k, v in dictionary.items():
            if len(v)>=2:
                return_list.append(v)
    return return_list

# %%
all_anagram_list(word_list)
# Out:
# [["rolando's", "orlando's"],
#  ['morals', 'molars'],
#  ['programers', 'reprograms'],
#  ['rate', 'tare', 'tear'],
#  ['escher', 'cheers'],
#  ['wraps', 'warps'],
#  ['streams', 'masters'],
#  ['ashed', 'shade', 'heads', 'hades'],
#  ['elides', 'diesel'],
#  ['junta', 'jaunt'],
#  ['vernal', 'lavern'],
#  ['leeriest', 'steelier'],
#  ['heptagons', 'pathogens'],
#  ["erse's", "seer's"],
#  ['snoop', 'spoon'],
#  ['refill', 'filler'],
#  ['chore', 'ocher', 'roche', 'ochre'],
#  ['rescinds', 'discerns'],
#  ["khan's", "hank's", "ankh's"],
#  ['cavalries', 'cavaliers'],
#  ['atom', 'moat'],
#  ['benton', 'bonnet'],
#  ['canny', 'nancy'],
#  ["lisp's", "slip's"],
#  ["diary's", "dairy's"],
#  ['weirdos', 'dowries', 'rowdies'],
#  ['slither', 'hitlers'],
#  ['moonstone', 'monotones'],
#  ['tensor', 'sterno', 'nestor', 'tenors', 'stoner'],
#  ['entraps', 'pastern', 'napster', 'parents'],
#  ['nattier', 'nitrate'],
#  ['evelyn', 'evenly'],
#  ['ideas', 'sadie', 'aides', 'aside'],
#  ['spatter', 'patters'],
#  ['conservation', 'conversation'],
#  ['attic', 'tacit'],
#  ['alberto', 'latrobe'],
#  ['else', 'lees', 'eels'],
#  ['oust', 'outs'],
#  ['hairsbreadth', 'hairbreadths'],
#  ['akron', 'koran'],
#  ['sparsest', 'trespass'],
#  ["lapse's", "sepal's"],
#  ["oval's", "olav's"],
#  ['asps', 'saps', 'pass', 'spas'],
#  ['ayes', 'yeas', 'easy'],
#  ['mirage', 'margie', 'gamier'],
#  ['nets', 'tens', 'sent', 'nest'],
#  ['martian', 'martina'],
#  ["ideal's", "delia's"],
#  ['decor', 'cored', 'credo'],
#  ["list's", "slit's", "silt's"],
#  ['licks', 'slick'],
#  ["read's", "dear's", "dare's"],
#  ["brut's", "burt's"],
#  ['realization', 'rationalize'],
#  ['shoot', 'hoots', 'sooth'],
#  ["bean's", "bane's"],
#  ['vlasic', 'cavils', 'slavic'],
#  ['lag', 'gal'],
#  ["rub's", "bur's"],
#  ['hera', 'hare', 'rhea', 'hear'],
#  ['girdles', 'gliders'],
#  ["friend's", "finder's"],
#  ['alga', 'gala'],
#  ["tucson's", "tuscon's"],
#  ['crapes', 'recaps', 'capers', 'scrape', 'parsec'],
#  ['dos', 'sod'],
#  ['trailing', 'trialing'],
#  ['granted', 'dragnet'],
#  ["gazer's", "graze's"],
#  ['stressed', 'desserts'],
#  ['lorgnettes', 'longstreet'],
#  ['arden', 'andre', 'daren', 'nader'],
#  ['sara', 'saar'],
#  ["brooke's", "booker's"],
#  ["result's", "luster's", "lustre's", "rustle's", "ulster's"],
#  ['tokyo', 'kyoto'],
#  ['keels', 'sleek', 'leeks'],
#  ["lab's", "alb's"],
#  ["lineman's", "melanin's"],
#  ['iyar', 'airy'],
#  ['oldies', 'isolde', 'soiled'],
#  ['rues', 'ruse', 'user', 'sure'],
#  ['cloture', 'coulter'],
#  ['loan', 'nola'],
#  ["salve's", "slave's"],
#  ['pave', 'vape'],
#  ['potash', 'pathos'],
#  ['birther', 'rebirth'],
#  ["span's", "snap's"],
#  ['ethics', 'itches'],
#  ['gnarliest', 'integrals', 'triangles'],
#  ['harps', 'sharp'],
#  ['palsy', 'plays', 'splay'],
#  ['tientsin', 'tinniest'],
#  ['spree', 'speer', 'peers'],
#  ['spawn', 'pawns'],
#  ['capes', 'paces', 'space'],
#  ['townes', 'weston'],
#  ['usurper', 'pursuer'],
#  ["sid's", "dis's"],
#  ['outlays', 'layouts'],
#  ['ancienter', 'nectarine'],
#  ['mir', 'rim'],
#  ["titan's", "taint's"],
#  ["deification's", "edification's"],
#  ['details', 'dilates'],
#  ['based', 'beads'],
#  ["conrail's", "clarion's"],
#  ['relayed', 'layered'],
#  ['tors', 'rots', 'sort'],
#  ['altitudes', 'latitudes'],
#  ['carole', 'oracle'],
#  ['aloft', 'float'],
#  ['lois', 'soil', 'oils', 'silo', 'soli'],
#  ['tamps', 'stamp'],
#  ["tosca's", "coast's", "ascot's"],
#  ["aden's", "dena's", "edna's", "dane's", "dean's"],
#  ['slates', 'tassel', 'steals', 'stales'],
#  ['doe', 'ode'],
#  ["gum's", "mug's"],
#  ['raises', 'arises'],
#  ['orange', 'genaro'],
#  ['gradient', 'treading'],
#  ['breast', 'barest'],
#  ['melanin', 'lineman'],
#  ['singer', 'signer', 'resign', 'reigns', 'ingres'],
#  ['loans', 'sloan', 'salon'],
#  ['eat', 'ate', 'eta', 'tea'],
#  ["smile's", "selim's", "miles's", "slime's"],
#  ['accoutrements', 'accouterments'],
#  ['toppings', 'stopping'],
#  ['castillo', 'callisto'],
#  ['nabs', 'bans'],
#  ['sedna', 'danes', 'deans', 'andes', 'sedan', 'snead'],
#  ['flit', 'lift'],
#  ['relay', 'leary', 'early', 'layer'],
#  ['once', 'cone'],
#  ["jaunt's", "junta's"],
#  ['chisel', 'chiles'],
#  ['skit', 'kits'],
#  ['curate', 'acuter'],
#  ['ipecac', 'icecap'],
#  ["glare's", "large's", "elgar's", "lager's", "alger's"],
#  ['la', 'al'],
#  ['souped', 'pseudo'],
#  ['suitcase', 'sauciest'],
#  ["kline's", "klein's"],
#  ['riven', 'ervin'],
#  ["serial's", "israel's"],
#  ['tonier', 'orient'],
#  ['cackling', 'clacking'],
#  ["startup's", "upstart's"],
#  ['bales', 'basel', 'sable'],
#  ['snatched', 'stanched'],
#  ['ear', 'rae', 'era', 'are'],
#  ["tao's", "oat's"],
#  ["ural's", "raul's"],
#  ["ing's", "gin's"],
#  ['paths', 'staph'],
#  ['drag', 'grad'],
#  ["triage's", "gaiter's"],
#  ['how', 'who'],
#  ["amy's", "yam's", "may's"],
#  ["trippe's", "tipper's"],
#  ['detest', 'tested'],
#  ['fife', 'fief'],
#  ['sleepers', 'peerless'],
#  ['cassinos', 'caissons'],
#  ['pairs', 'parsi', 'paris'],
#  ['safer', 'fears', 'fares'],
#  ["melba's", "mable's", "mabel's", "blame's", "amble's"],
#  ['adler', 'alder'],
#  ['handcar', 'chandra'],
#  ['girt', 'grit', 'trig'],
#  ['pastes', 'spates'],
#  ['opt', 'pot', 'top'],
#  ['tarpons', 'patrons'],
#  ['caterers', 'terraces', 'retraces'],
#  ['bedlam', 'lambed', 'blamed', 'ambled'],
#  ['sirup', 'prius'],
#  ["recreant's", "terrance's"],
#  ['years', 'ayers'],
#  ['periled', 'replied'],
#  ['ratings', 'staring'],
#  ["galen's", "angle's", "angel's"],
#  ["act's", "cat's"],
#  ['sink', 'inks', 'skin'],
#  ['peppier', 'preppie'],
#  ['gina', 'agni', 'gain'],
#  ['blither', 'hilbert'],
#  ['ringside', 'residing', 'desiring'],
#  ["strait's", "artist's"],
#  ['insures', 'sunrise'],
#  ['truest', 'utters'],
#  ['trendier', 'interred'],
#  ["scat's", "acts's", "cast's"],
#  ['terran', 'errant', 'ranter'],
#  ['censers', 'screens'],
#  ["till's", "lilt's"],
#  ['transept', 'patterns'],
#  ['earthiest', 'heartiest'],
#  ['adroitly', 'idolatry', 'dilatory'],
#  ["specter's", "scepter's", "respect's"],
#  ['talent', 'latent'],
#  ['sleazier', 'realizes'],
#  ["craig's", "cigar's"],
#  ['parceled', 'replaced'],
#  ['thebes', 'behest'],
#  ['forensic', 'conifers'],
#  ['drapes', 'parsed', 'spread', 'padres', 'spared', 'rasped'],
#  ['menorahs', 'horseman'],
#  ['nations', 'anoints'],
#  ['cattily', 'tacitly'],
#  ['demurring', 'murdering'],
#  ["astor's", "sarto's", "roast's"],
#  ['weddell', 'dwelled'],
#  ['negroid', 'ignored', 'eroding', 'redoing'],
#  ['sera', 'sear', 'ares', 'eras', 'ears'],
#  ['mayors', 'morays'],
#  ['amour', 'mauro'],
#  ["cold's", "clod's"],
#  ['rousing', 'souring'],
#  ["tamra's", "marat's", "marta's"],
#  ['rereads', 'readers'],
#  ["odin's", "dion's", "dino's"],
#  ['lolcat', 'tlaloc'],
#  ['learnt', 'rental', 'antler'],
#  ['sheol', 'holes'],
#  ['oodles', 'loosed', 'soloed'],
#  ['brute', 'rebut', 'tuber'],
#  ['ogles', 'loges'],
#  ['mariadb', 'barmaid'],
#  ['ogre', 'ergo', 'roeg', 'gore'],
#  ['fora', 'afro'],
#  ['saviour', 'various'],
#  ['dora', 'road'],
#  ['beets', 'beset'],
#  ['latrines', 'entrails'],
#  ['slough', 'ghouls'],
#  ['fro', 'for'],
#  ['arms', 'mars', 'rams'],
#  ["prod's", "drop's"],
#  ['student', 'stunted'],
#  ['mired', 'rimed', 'dimer'],
#  ['marcy', 'camry'],
#  ['reality', 'irately'],
#  ['schematics', 'catechisms'],
#  ['speck', 'pecks'],
#  ['slowed', 'dowels'],
#  ["maul's", "alum's"],
#  ["gallo's", "algol's"],
#  ['root', 'oort'],
#  ['fried', 'fired'],
#  ['maroon', 'romano'],
#  ['magnate', 'magenta'],
#  ['browse', 'bowers'],
#  ['sapporo', 'apropos'],
#  ['void', 'ovid'],
#  ['keri', 'erik'],
#  ["sprite's", "stripe's", "priest's"],
#  ['hardy', 'hydra'],
#  ['spilt', 'split'],
#  ["oriental's", "relation's"],
#  ['pelts', 'slept', 'spelt'],
#  ['interim', 'termini', 'mintier'],
#  ["oscillation's", "colonialist's"],
#  ["pogo's", "goop's"],
#  ['depraved', 'pervaded'],
#  ['pones', 'epson', 'opens', 'peons'],
#  ["randell's", "darnell's"],
#  ['resort', 'sorter', 'roster', 'torres'],
#  ["garner's", "ranger's"],
#  ["lifer's", "rifle's", "flier's"],
#  ['speech', 'cheeps'],
#  ['quito', 'quoit'],
#  ['tonal', 'alton', 'talon'],
#  ['unison', 'unions'],
#  ['lister', 'liters'],
#  ['tesla', 'steal', 'slate', 'least', 'stael', 'stale', 'teals', 'tales'],
#  ['debugs', 'budges'],
#  ['repents', 'present', 'serpent'],
#  ["ismael's", "melisa's"],
#  ['skyed', 'dykes'],
#  ["warren's", "warner's"],
#  ['converge', 'congreve'],
#  ['keens', 'knees'],
#  ["elbow's", "bowel's"],
#  ['seams', 'mesas', 'sames'],
#  ['erratic', 'cartier'],
#  ['recheck', 'checker'],
#  ['upset', 'setup'],
#  ["viewer's", "review's"],
#  ['leno', 'lone', 'leon', 'noel', 'olen'],
#  ['sectors', 'corsets', 'escorts'],
#  ["bernanke's", "banneker's"],
#  ["chum's", "much's"],
#  ['heartier', 'earthier'],
#  ['sounder', 'resound'],
#  ["mores's", "morse's"],
#  ["dora's", "road's"],
#  ['threads', 'hardest', 'trashed', 'hatreds', 'dearths'],
#  ['tinned', 'indent', 'dentin', 'intend'],
#  ['bake', 'beak'],
#  ['boner', 'borne'],
#  ["lin's", "nil's"],
#  ['fauns', 'snafu'],
#  ["rapine's", "panier's", "napier's"],
#  ['agar', 'raga', 'agra'],
#  ['hobs', 'bosh'],
#  ["spat's", "past's"],
#  ["berle's", "rebel's"],
#  ['elise', 'elsie'],
#  ['demeter', 'metered'],
#  ['tokes', 'stoke'],
#  ['nieves', 'envies'],
#  ['coeds', 'codes'],
#  ['infringed', 'friending'],
#  ['scalloping', 'collapsing'],
#  ['carmella', 'marcella'],
#  ['timbres', 'timbers'],
#  ['trellis', 'stiller', 'tillers'],
#  ['keening', 'kneeing'],
#  ['chap', 'caph'],
#  ['gates', 'stage'],
#  ['tankers', 'rankest'],
#  ["kris's", "risk's"],
#  ['colones', 'console'],
#  ['mundane', 'unnamed'],
#  ['topically', 'optically'],
#  ['easter', 'teresa', 'eaters', 'teaser'],
#  ['wolfs', 'flows', 'fowls'],
#  ['liars', 'rails', 'liras', 'lairs'],
#  ['beseech', 'beeches'],
#  ['article', 'recital'],
#  ['coed', 'code'],
#  ['crimson', 'microns'],
#  ['dawns', 'wands'],
#  ['charon', 'anchor'],
#  ['puree', 'rupee'],
#  ['shad', 'dash'],
#  ["amaru's", "maura's"],
#  ['despair', 'aspired', 'diapers', 'praised'],
#  ["nassau's", "susana's"],
#  ["ruse's", "user's"],
#  ['pediatrics', 'patricides'],
#  ["armenian's", "annmarie's", "marianne's"],
#  ['goths', 'ghost'],
#  ["osman's", "mason's"],
#  ['finer', 'infer'],
#  ['cheaters', 'hectares', 'teachers'],
#  ['erasmus', 'masseur'],
#  ["solo's", "oslo's"],
#  ['replay', 'parley', 'player', 'pearly'],
#  ["ginkgo's", "gingko's"],
#  ['stickpin', 'nitpicks'],
#  ["lien's", "neil's", "nile's", "line's"],
#  ['lenore', 'lorene'],
#  ["searcher's", "research's"],
#  ['palsying', 'splaying'],
#  ['saxon', 'axons'],
#  ['chasers', 'crashes'],
#  ['saw', 'aws', 'was'],
#  ['retire', 'terrie'],
#  ['genera', 'enrage'],
#  ['polythene', 'telephony'],
#  ['wiser', 'weirs', 'wires'],
#  ['sergeants', 'estranges', 'greatness'],
#  ["dingo's", "doing's"],
#  ['orate', 'erato'],
#  ['chester', 'retches', 'etchers'],
#  ["wendi's", "edwin's"],
#  ['marrieds', 'admirers'],
#  ['need', 'eden'],
#  ['buster', 'brutes', 'rebuts', 'tubers'],
#  ['resold', 'solder'],
#  ['parroted', 'prorated', 'teardrop', 'predator'],
#  ['goop', 'pogo'],
#  ['bombing', 'mobbing'],
#  ['node', 'deon', 'done'],
#  ['twits', 'twist'],
#  ['adeline', 'aliened'],
#  ['sports', 'strops'],
#  ['wonder', 'downer'],
#  ["bristle's", "blister's"],
#  ['maura', 'amaru'],
#  ["robyn's", "bryon's", "byron's"],
#  ['sheik', 'hikes'],
#  ['pits', 'spit', 'tips'],
#  ["crooner's", "coroner's"],
#  ['spam', 'amps', 'maps'],
#  ['olga', 'goal'],
#  ['reinterpret', 'interpreter'],
#  ['caduceus', 'caucused'],
#  ["bates's", "beast's"],
#  ['harkens', 'hankers'],
#  ['calmer', 'marcel'],
#  ['fillers', 'refills'],
#  ['percale', 'replace'],
#  ['drab', 'brad', 'bard'],
#  ["senate's", "sateen's"],
#  ['enable', 'baleen'],
#  ['sander', 'snared', 'andres'],
#  ['equip', 'pique'],
#  ['film', 'milf'],
#  ["gather's", "gareth's"],
#  ['patsies', 'pasties'],
#  ['electra', 'treacle'],
#  ['spinal', 'plains'],
#  ['tins', 'nits', 'snit'],
#  ["lauri's", "luria's"],
#  ['laity', 'italy'],
#  ['sheeting', 'seething'],
#  ['cronies', 'ericson'],
#  ['elates', 'estela', 'teasel'],
#  ["leak's", "kale's", "lake's"],
#  ['smartened', 'tradesmen'],
#  ["urination's", "ruination's"],
#  ["cholera's", "chorale's"],
#  ['laze', 'zeal'],
#  ['stewart', 'swatter'],
#  ['yaws', 'ways', 'sway'],
#  ["beater's", "rebate's"],
#  ['atreus', 'seurat'],
#  ["petersen's", "pretense's"],
#  ['mechanics', 'mischance'],
#  ["wear's", "ware's"],
#  ['carbides', 'ascribed'],
#  ["parcel's", "placer's", "carpel's"],
#  ["trina's", "train's"],
#  ["rule's", "lure's"],
#  ['velma', 'melva'],
#  ['tooled', 'toledo', 'looted'],
#  ["lana's", "alan's"],
#  ['theologians', 'anthologies'],
#  ['sims', 'miss', 'isms'],
#  ['tellers', 'retells'],
#  ['grounded', 'underdog'],
#  ['angled', 'dangle', 'glenda'],
#  ['cackled', 'clacked'],
#  ['duelist', 'dilutes'],
#  ["shaw's", "wash's"],
#  ['recipes', 'precise', 'pierces'],
#  ['name', 'amen', 'mean', 'mane'],
#  ["daze's", "adze's"],
#  ["leap's", "pale's", "plea's", "peal's"],
#  ['erect', 'crete'],
#  ['mesa', 'seam', 'same'],
#  ['intrude', 'untried'],
#  ['ypres', 'preys', 'pyres'],
#  ['lapsing', 'palings', 'sapling'],
#  ['divan', 'dvina', 'viand'],
#  ['higgins', 'sighing'],
#  ["morn's", "norm's"],
#  ['stow', 'tows', 'twos'],
#  ['dire', 'ride', 'reid'],
#  ["crepe's", "creep's"],
#  ['reforests', 'foresters'],
#  ['tooling', 'looting'],
#  ['domes', 'modes', 'demos'],
#  ['bordello', 'doorbell'],
#  ["hectare's", "teacher's", "cheater's"],
#  ['distaste', 'staidest'],
#  ['norma', 'moran', 'ramon', 'manor', 'roman'],
#  ['issue', 'susie'],
#  ['theatre', 'theater'],
#  ['marbles', 'rambles'],
#  ['intenser', 'internes'],
#  ['curies', 'cruise'],
#  ['impresses', 'premisses'],
#  ["keats's", "stake's", "skate's", "steak's"],
#  ["loge's", "ogle's", "lego's"],
#  ['roomer', 'romero'],
#  ['ecru', 'cure'],
#  ['desert', 'rested', 'deters'],
#  ['lats', 'slat', 'last', 'salt'],
#  ["bus's", "sub's", "ubs's"],
#  ['alert', 'alter', 'later'],
#  ['hinges', 'neighs'],
#  ['pram', 'ramp'],
#  ['sidearms', 'misreads'],
#  ['coordinate', 'decoration'],
#  ['pearled', 'pleader'],
#  ['depend', 'pended'],
#  ['simplest', 'misspelt'],
#  ['settlers', 'trestles'],
#  ['xe', 'ex'],
#  ["bounder's", "rebound's"],
#  ['sahel', 'shale', 'heals', 'leash', 'hales'],
#  ['menials', 'seminal'],
#  ['laura', 'aural'],
#  ['dikes', 'skied'],
#  ['precipitate', 'peripatetic'],
#  ['mindless', 'mildness'],
#  ["milestone's", "limestone's"],
#  ['lab', 'alb'],
#  ['lifers', 'fliers', 'rifles'],
#  ['bangor', 'brogan'],
#  ['setters', 'testers', 'streets', 'tersest'],
#  ["lhotse's", "hostel's"],
#  ['elastics', 'scaliest', 'alcestis'],
#  ['craven', 'cavern'],
#  ['vaster', 'averts', 'starve'],
#  ['meeting', 'teeming'],
#  ["peel's", "pele's"],
#  ['sower', 'swore', 'worse'],
#  ['orgies', 'sergio'],
#  ['cat', 'act'],
#  ["won's", "now's"],
#  ['tilts', 'stilt'],
#  ['reprise', 'respire'],
#  ["least's", "steal's", "slate's", "tesla's", "stael's"],
#  ["arno's", "nora's", "aron's", "oran's", "roan's"],
#  ['orval', 'valor'],
#  ['trifling', 'flirting'],
#  ['austin', 'unitas'],
#  ['apter', 'prate', 'taper', 'petra'],
#  ['coexist', 'exotics'],
#  ["body's", "boyd's"],
#  ['halts', 'laths', 'shalt'],
#  ['lenny', 'lynne'],
#  ['drive', 'verdi', 'diver'],
#  ['tenon', 'tonne'],
#  ['rices', 'cries'],
#  ["anvil's", "alvin's"],
#  ['nerdiest', 'dniester', 'resident', 'inserted', 'trendies'],
#  ['crashing', 'chagrins'],
#  ["dunbar's", "durban's"],
#  ['macho', 'mocha'],
#  ['deep', 'peed'],
#  ["sonar's", "arson's"],
#  ['saddle', 'addles'],
#  ['dungaree', 'underage'],
#  ['item', 'emit', 'mite', 'time'],
#  ['blest', 'belts'],
#  ['lank', 'klan'],
#  ['keystone', 'keynotes'],
#  ["emo's", "moe's"],
#  ['detour', 'toured', 'routed'],
#  ['recasting', 'caterings'],
#  ['bittern', 'britten'],
#  ['stewed', 'tweeds'],
#  ['otter', 'torte'],
#  ['velours', 'louvers'],
#  ["ila's", "ali's"],
#  ["nivea's", "evian's"],
#  ['mat', 'tam'],
#  ['feints', 'infest', 'finest'],
#  ["dorian's", "inroad's"],
#  ['niggas', 'agings'],
#  ['replacing', 'parceling'],
#  ['flowed', 'wolfed', 'fowled'],
#  ['roasts', 'assort'],
#  ['tartan', 'rattan'],
#  ['daley', 'delay'],
#  ['colonialist', 'oscillation'],
#  ["aery's", "year's"],
#  ['forge', 'gofer'],
#  ['zeus', 'suez'],
#  ['earbud', 'dauber'],
#  ['costar', 'croats', 'actors', 'scrota', 'castro', 'castor'],
#  ['wonders', 'downers'],
#  ["nobel's", "noble's"],
#  ['flemish', 'himself'],
#  ["sadie's", "aside's"],
#  ['marianne', 'annmarie', 'armenian'],
#  ['compile', 'polemic'],
#  ['hustling', 'sunlight'],
#  ['sakai', 'kasai'],
#  ['ebony', 'boney'],
#  ['streaming', 'mastering', 'emigrants'],
#  ["leila's", "lelia's", "allie's"],
#  ['route', 'outer'],
#  ['wings', 'swing'],
#  ['wolves', 'vowels'],
#  ['sating', 'giants'],
#  ['able', 'abel', 'bela', 'bale', 'elba'],
#  ["girth's", "right's"],
#  ['turnover', 'overturn'],
#  ['tore', 'rote'],
#  ['empires', 'premise'],
#  ['triteness', 'interests'],
#  ["shan't", "hasn't"],
#  ['disperse', 'presides'],
#  ['sifter', 'strife', 'rifest', 'refits'],
#  ["wrap's", "warp's"],
#  ['lobe', 'bole'],
#  ['ardent', 'ranted'],
#  ["scalp's", "clasp's"],
#  ['moaned', 'daemon'],
#  ['ruble', 'bluer'],
#  ["asp's", "sap's", "spa's"],
#  ['decimate', 'medicate'],
#  ['worker', 'rework'],
#  ['lump', 'plum'],
#  ['elapses', 'pleases'],
#  ['mona', 'oman', 'moan'],
#  ["elma's", "male's", "meal's", "elam's", "lame's"],
#  ['answers', 'rawness'],
#  ['insatiable', 'banalities'],
#  ['perseid', 'preside'],
#  ["pane's", "nape's", "pena's"],
#  ["outlay's", "layout's"],
#  ['taunted', 'attuned'],
#  ['mable', 'blame', 'mabel', 'melba', 'amble'],
#  ['miters', 'merits', 'mister', 'remits', 'timers'],
#  ['many', 'myna'],
#  ['corey', 'royce', 'coyer'],
#  ['armfuls', 'armsful'],
#  ['anvils', 'silvan'],
#  ['nerves', 'severn'],
#  ['andrews', 'wardens', 'wanders'],
#  ["statement's", "testament's"],
#  ['umps', 'sump'],
#  ['conrad', 'candor', 'dacron'],
#  ['loudest', 'tousled'],
#  ["contrail's", "cilantro's"],
#  ['sallow', 'allows'],
#  ['scalene', 'cleanse'],
#  ["tran's", "rant's"],
#  ['now', 'own', 'won'],
#  ['cupola', 'copula'],
#  ["ram's", "arm's", "mar's"],
#  ["raw's", "war's"],
#  ['newt', 'went'],
#  ["incest's", "insect's"],
#  ['klein', 'liken', 'kline'],
#  ['complies', 'compiles', 'polemics'],
#  ["megaton's", "montage's", "magneto's"],
#  ['agree', 'eager'],
#  ['restarts', 'starters'],
#  ['stint', 'tints'],
#  ["saddam's", "addams's"],
#  ['taoisms', 'maoists'],
#  ["altitude's", "latitude's"],
#  ['inkling', 'kilning', 'linking'],
#  ['punters', 'punster'],
#  ["pan's", "nap's"],
#  ['rares', 'serra', 'rears'],
#  ['oars', 'rosa', 'soar'],
#  ['dot', 'tod'],
#  ['splendid', 'spindled'],
#  ["mervin's", "vermin's"],
#  ["velcro's", "clover's"],
#  ['basin', 'sabin'],
#  ["car's", "arc's", "rca's"],
#  ['maine', 'anime'],
#  ['smash', 'shams'],
#  ['stances', 'ascents'],
#  ["ante's", "etna's", "nate's"],
#  ["id's", "di's"],
#  ['files', 'flies'],
#  ["vial's", "vila's"],
#  ['developers', 'redevelops'],
#  ['hocking', 'choking'],
#  ['seabird', 'braised', 'sidebar'],
#  ['peron', 'prone'],
#  ['tritest', 'titters'],
#  ['quieter', 'requite'],
#  ['brigades', 'abridges'],
#  ['folgers', 'golfers'],
#  ['singing', 'signing'],
#  ['rival', 'viral'],
#  ['canopying', 'poignancy'],
#  ['huntsman', 'manhunts'],
#  ['stabling', 'blasting'],
#  ['mit', 'tim'],
#  ['caring', 'arcing', 'racing'],
#  ["soil's", "lois's", "silo's"],
#  ['indices', 'incised'],
#  ['lumps', 'slump', 'plums'],
#  ["lesion's", "insole's"],
#  ['mores', 'romes', 'morse'],
#  ["charisma's", "archaism's"],
#  ['proudest', 'postured', 'sprouted'],
#  ['shotguns', 'gunshots'],
#  ['alyce', 'lacey'],
#  ['ugliest', 'gluiest'],
#  ['rode', 'doer', 'oder', 'redo'],
#  ['knits', 'stink'],
#  ['toed', 'dote'],
#  ['ilks', 'silk'],
#  ['tense', 'teens'],
#  ['warehouses', 'housewares'],
#  ['rising', 'siring'],
#  ['cowers', 'escrow'],
#  ["lena's", "lane's", "lean's", "neal's"],
#  ["over's", "rove's"],
#  ['veriest', 'restive'],
#  ['si', 'is'],
#  ['albion', 'albino'],
#  ["labrador's", "larboard's"],
#  ['inclosure', 'cornelius'],
#  ['raves', 'saver', 'avers'],
#  ['cassock', 'cossack'],
#  ['dines', 'snide', 'denis'],
#  ['astir', 'stair', 'sitar'],
#  ['rhodes', 'hordes', 'horsed', 'shored'],
#  ['fortieths', 'frothiest'],
#  ['dignifies', 'signified'],
#  ["palmer's", "marple's"],
#  ['delivers', 'silvered', 'slivered'],
#  ['stare', 'taser', 'tears', 'tares', 'rates', 'aster'],
#  ['scrapes', 'parsecs'],
#  ["manual's", "alumna's"],
#  ['atolls', 'allots'],
#  ['restoring', 'resorting'],
#  ["tale's", "teal's", "leta's"],
#  ['grudging', 'drugging'],
#  ['continued', 'unnoticed'],
#  ['infests', 'fitness'],
#  ['gracie', 'cagier'],
#  ['renters', 'sterner'],
#  ["harlem's", "mahler's"],
#  ['dorset', 'sorted', 'stored', 'strode'],
#  ["tardiness's", "streisand's"],
#  ['tolyatti', 'totality'],
#  ['calks', 'lacks', 'slack'],
#  ['leif', 'life', 'lief', 'file'],
#  ['logarithms', 'algorithms'],
#  ['sombrely', 'somberly'],
#  ["moray's", "mayor's"],
#  ['smarter', 'armrest'],
#  ['retweets', 'tweeters'],
#  ["sorbet's", "osbert's", "strobe's"],
#  ["nit's", "tin's", "isn't"],
#  ["eden's", "need's"],
#  ['voided', 'devoid'],
#  ['concerting', 'concreting'],
#  ['fondus', 'founds'],
#  ['initiated', 'dietitian'],
#  ['redhead', 'adhered'],
#  ['loop', 'pool', 'polo'],
#  ['shook', 'hooks'],
#  ['novels', 'sloven'],
#  ["plane's", "panel's", "nepal's"],
#  ["diver's", "verdi's", "drive's"],
#  ['prince', 'pincer'],
#  ["proteus's", "posture's"],
#  ["atria's", "atari's", "tiara's"],
#  ["kristen's", "stinker's", "kirsten's"],
#  ['peek', 'keep'],
#  ['riel', 'rile', 'lire'],
#  ['sheba', 'hbase'],
#  ['ella', 'lela'],
#  ['certifications', 'rectifications'],
#  ['orientating', 'integration'],
#  ['nomad', 'damon'],
#  ["heron's", "horne's", "rhone's"],
#  ['burl', 'blur'],
#  ['stead', 'sated', 'dates'],
#  ['girts', 'grits', 'grist'],
#  ['puns', 'spun'],
#  ['incest', 'nicest', 'insect'],
#  ["soto's", "soot's"],
#  ['caliper', 'replica'],
#  ['nested', 'tensed'],
#  ['star', 'arts', 'tsar', 'tars', 'rats'],
#  ['stoker', 'stroke'],
#  ['decals', 'scaled'],
#  ['potions', 'options'],
#  ["lorre's", "errol's"],
#  ['ticks', 'stick'],
#  ['regina', 'regain'],
#  ['pasteur', 'pasture'],
#  ['printings', 'sprinting'],
#  ['pinking', 'kingpin'],
#  ['demoniac', 'comedian'],
#  ['altair', 'lariat'],
#  ["argon's", "groan's", "organ's"],
#  ["singer's", "signer's", "ingres's"],
#  ['toiler', 'loiter'],
#  ["resident's", "dniester's"],
#  ["anime's", "maine's"],
#  ['despot', 'posted', 'depots'],
#  ['york', 'kory'],
#  ['wormwood', 'woodworm'],
#  ["verna's", "raven's"],
#  ['dingy', 'dying'],
#  ["irtish's", "tishri's"],
#  ['bidet', 'debit'],
#  ['resumption', 'importunes'],
#  ['masher', 'harems'],
#  ['nosed', 'nodes'],
#  ['canter', 'recant', 'nectar', 'trance', 'cretan'],
#  ['satanism', 'mantissa'],
#  ['martel', 'armlet'],
#  ['stabled', 'blasted', 'baldest'],
#  ['manuela', 'alumnae'],
#  ["romance's", "cameron's"],
#  ['peters', 'pester', 'preset'],
#  ["gardenia's", "drainage's"],
#  ['demotion', 'motioned'],
#  ['bushels', 'blushes'],
#  ['prigs', 'sprig', 'grips'],
#  ["alden's", "nelda's"],
#  ['usurpers', 'pursuers'],
#  ["pest's", "step's"],
#  ['alcindor', 'ironclad'],
#  ['titling', 'tlingit', 'tilting'],
#  ['turnovers', 'overturns'],
#  ['melded', 'meddle'],
#  ['corps', 'crops'],
#  ['reorgs', 'rogers'],
#  ['mercado', 'caromed', 'comrade'],
#  ['indenting', 'intending'],
#  ['sledging', 'geldings'],
#  ["nepali's", "alpine's"],
#  ["aisle's", "elias's", "elisa's"],
#  ['cinema', 'anemic'],
#  ['producer', 'procured'],
#  ['sliver', 'silver', 'livers'],
#  ['olsen', 'noels'],
#  ["kate's", "teak's", "take's"],
#  ["ella's", "lela's"],
#  ["elnora's", "lenora's", "elanor's", "loaner's", "lorena's"],
#  ['linkage', 'leaking'],
#  ['daniel', 'nailed', 'alined', 'denial'],
#  ['brawlers', 'warblers'],
#  ['tautest', 'statute'],
#  ['wired', 'weird', 'wider'],
#  ['noelle', 'leonel'],
#  ['meagan', 'manage'],
#  ["lewis's", "wiles's"],
#  ['flier', 'rifle', 'lifer'],
#  ['flees', 'feels'],
#  ['singers', 'signers', 'resigns', 'ingress'],
#  ['yemen', 'enemy'],
#  ['ankhs', 'shank', 'khans', 'hanks'],
#  ['robing', 'boring'],
#  ['earliest', 'ateliers'],
#  ['hates', 'heats', 'haste'],
#  ['seedier', 'desiree'],
#  ['disks', 'skids'],
#  ['supers', 'purses'],
#  ['tutsi', 'titus'],
#  ['stile', 'tiles', 'islet'],
#  ['overdose', 'overdoes'],
#  ['emanates', 'manatees'],
#  ['shouts', 'souths'],
#  ['logan', 'anglo', 'golan', 'along'],
#  ['feeling', 'fleeing'],
#  ['plugins', 'pulsing'],
#  ['sidney', 'disney'],
#  ['lattice', 'tactile'],
#  ['plaint', 'pliant'],
#  ['dallies', 'sallied'],
#  ['remake', 'kareem'],
#  ['staples', 'pastels'],
#  ['redis', 'rides', 'sired', 'dries'],
#  ['thing', 'night'],
#  ["bosnia's", "bonsai's"],
#  ['crochets', 'crotches'],
#  ['archie', 'achier'],
#  ["rethink's", "thinker's"],
#  ['enters', 'sterne', 'tenser', 'ernest', 'resent'],
#  ['transient', 'intranets'],
#  ['barley', 'bleary', 'barely'],
#  ['deform', 'formed'],
#  ["nigga's", "aging's"],
#  ["pinto's", "piton's", "point's"],
#  ["bangle's", "bengal's"],
#  ['rotates', 'rosetta', 'toaster'],
#  ['ac', 'ca'],
#  ['islams', 'missal'],
#  ['belgian', 'bengali', 'algenib'],
#  ['enfolds', 'fondles'],
#  ["prattle's", "platter's"],
#  ['hits', 'shit', 'this'],
#  ['flared', 'alfred'],
#  ["fern's", "nerf's"],
#  ['lots', 'slot', 'lost'],
#  ['slides', 'sidles'],
#  ['thor', 'roth'],
#  ["ubangi's", "bangui's"],
#  ['swearer', 'wearers'],
#  ["thermos's", "smother's"],
#  ["emusic's", "cesium's", "miscue's"],
#  ['ales', 'elsa', 'lesa', 'leas', 'sale', 'seal'],
#  ["cedar's", "cadre's"],
#  ["shaka's", "sakha's"],
#  ['grater', 'garret', 'garter'],
#  ['mel', 'elm'],
#  ['delights', 'slighted'],
#  ['boer', 'bore', 'ebro', 'robe'],
#  ['configures', 'refocusing'],
#  ["pasty's", "patsy's"],
#  ['nashua', 'shauna'],
#  ["tonga's", "tango's"],
#  ['spate', 'paste', 'tapes', 'pates', 'septa'],
#  ["okra's", "karo's"],
#  ['touts', 'stout'],
#  ['devise', 'sieved'],
#  ['rapiers', 'repairs', 'raspier', 'parries'],
#  ['arline', 'linear'],
#  ["marciano's", "macaroni's"],
#  ["stoner's", "nestor's", "sterno's"],
#  ['repeals', 'relapse'],
#  ["sprout's", "stupor's", "proust's"],
#  ['grease', 'agrees'],
#  ['deposit', 'posited', 'topside', 'dopiest'],
#  ['bengal', 'bangle'],
#  ["team's", "meat's", "mate's"],
#  ['acrostic', 'socratic'],
#  ['overacts', 'overcast'],
#  ["canto's", "acton's"],
#  ['sourest', 'ousters'],
#  ['inonu', 'union'],
#  ['fended', 'defend'],
#  ['mailed', 'medial', 'imelda'],
#  ['brno', 'born'],
#  ['secretion', 'erections'],
#  ['lake', 'kale', 'leak'],
#  ['gaps', 'gasp'],
#  ["lima's", "mail's", "mali's"],
#  ["awl's", "law's"],
#  ['gallo', 'algol'],
#  ['vessel', 'selves'],
#  ['shear', 'rheas', 'hares', 'share', 'hears'],
#  ['nemesis', 'siemens'],
#  ["salon's", "sloan's"],
#  ["caisson's", "cassino's"],
#  ['stupor', 'sprout', 'proust'],
#  ['imams', 'maims'],
#  ['sprayer', 'prayers'],
#  ['predominates', 'impersonated'],
#  ['putin', 'input'],
#  ['oval', 'olav'],
#  ['tweeter', 'retweet'],
#  ['lin', 'nil'],
#  ['whale', 'wheal'],
#  ['sellouts', 'outsells'],
#  ["brno's", "born's"],
#  ['reveling', 'levering'],
#  ['gurgles', 'slugger'],
#  ['breath', 'bertha', 'bather'],
#  ['sub', 'ubs', 'bus'],
#  ['rape', 'pare', 'pear', 'earp', 'reap'],
#  ['bast', 'bats', 'stab', 'tabs'],
#  ['rinse', 'risen', 'reins', 'siren', 'resin'],
#  ['drooled', 'doodler'],
#  ['hassles', 'slashes'],
#  ["player's", "parley's", "replay's"],
#  ['flesh', 'shelf'],
#  ['envied', 'veined', 'endive'],
#  ['undated', 'daunted'],
#  ['plead', 'pedal', 'paled'],
#  ['uterus', 'suture'],
#  ['field', 'fidel', 'filed', 'flied'],
#  ['carlo', 'coral', 'carol'],
#  ['manley', 'laymen', 'meanly', 'namely'],
#  ["alba's", "baal's"],
#  ["timer's", "miter's", "merit's"],
#  ['cleaners', 'cleanser'],
#  ['tyros', 'troys', 'story'],
#  ['snatch', 'stanch', 'chants'],
#  ['glossing', 'goslings'],
#  ['boast', 'boats'],
#  ['deal', 'dale', 'lade', 'lead', 'leda'],
#  ['lacking', 'calking'],
#  ['porter', 'report'],
#  ['here', 'rhee'],
#  ['costing', 'gnostic'],
#  ['open', 'nope', 'peon', 'pone'],
#  ["so's", "os's"],
#  ['theresa', 'reheats', 'heaters'],
#  ['missile', 'similes'],
#  ['dirge', 'ridge'],
#  ["martel's", "armlet's"],
#  ['urinals', 'insular'],
#  ['flea', 'leaf'],
#  ["slut's", "lust's"],
#  ['stonier', 'orients'],
#  ['starch', 'charts'],
#  ['misprint', 'imprints'],
#  ['skirting', 'striking'],
#  ['shaw', 'haws', 'wash'],
#  ['neruda', 'unread'],
#  ['selection', 'elections'],
#  ['gape', 'page'],
#  ['blogs', 'globs'],
#  ['samson', 'masons'],
#  ['alba', 'baal'],
#  ['laden', 'alden', 'nelda'],
#  ['dales', 'leads', 'lades', 'deals'],
#  ['sat', 'ats'],
#  ['shower', 'whores'],
#  ['tracer', 'carter', 'crater'],
#  ['colonialists', 'oscillations'],
#  ['lime', 'emil', 'mile'],
#  ['purims', 'purism'],
#  ["wriggle's", "wiggler's"],
#  ["abode's", "adobe's"],
#  ['arc', 'rca', 'car'],
#  ['ashore', 'hoarse'],
#  ["suture's", "uterus's"],
#  ['sued', 'used', 'duse', 'dues'],
#  ["venetian's", "aventine's"],
#  ['crooner', 'coroner'],
#  ...]

# %%
# %time anagram_map = all_anagram_list(word_list)
# Out:
# CPU times: user 629 ms, sys: 373 ms, total: 1 s
# Wall time: 1.06 s

# %%
len(anagram_map)
# Out:
# 5872

# %% [markdown]
# ## Summary
#
# What is the point of the examples in this notebook?
#
# * The different versions of `is_anagram` show that, when inputs are small, it is hard to say which algorithm will be the fastest. It often depends on details of the implementation. Anyway, the differences tend to be small, so it might not matter much in practice.
#
# * The different algorithms we used to search for anagram pairs show that, when inputs are large, we can often tell which algorithm will be fastest. And the difference between a fast algorithm and a slow one can be huge!

# %% [markdown]
# ## Exercises
#
# Before you work on these exercises, you might want to read the Python [Sorting How-To](https://docs.python.org/3/howto/sorting.html). It uses `lambda` to define an anonymous function, which [you can read about here](https://www.w3schools.com/python/python_lambda.asp).
#
# **Exercise 7:**
# Make a dictionary like `anagram_map` that contains only keys that map to a list with more than one element. You can use a `for` loop to make a new dictionary, or a [dictionary comprehension](https://www.freecodecamp.org/news/dictionary-comprehension-in-python-explained-with-examples/).

# %%
def better_function(set_of_str):
    dictionary = {}
    return_list = []
    for word in set_of_str:
        sorted_word = ''.join(sorted(word))
        if sorted_word not in dictionary:
            dictionary[sorted_word] = [word]
        else:
            dictionary[sorted_word].append(word)
    
    #remove words with no anagrams
    for k, v in dictionary.items():
            if len(v)>=2:
                return_list.append(v)
    return return_list

better_function(word_list)
# Out:
# [["rolando's", "orlando's"],
#  ['morals', 'molars'],
#  ['programers', 'reprograms'],
#  ['rate', 'tare', 'tear'],
#  ['escher', 'cheers'],
#  ['wraps', 'warps'],
#  ['streams', 'masters'],
#  ['ashed', 'shade', 'heads', 'hades'],
#  ['elides', 'diesel'],
#  ['junta', 'jaunt'],
#  ['vernal', 'lavern'],
#  ['leeriest', 'steelier'],
#  ['heptagons', 'pathogens'],
#  ["erse's", "seer's"],
#  ['snoop', 'spoon'],
#  ['refill', 'filler'],
#  ['chore', 'ocher', 'roche', 'ochre'],
#  ['rescinds', 'discerns'],
#  ["khan's", "hank's", "ankh's"],
#  ['cavalries', 'cavaliers'],
#  ['atom', 'moat'],
#  ['benton', 'bonnet'],
#  ['canny', 'nancy'],
#  ["lisp's", "slip's"],
#  ["diary's", "dairy's"],
#  ['weirdos', 'dowries', 'rowdies'],
#  ['slither', 'hitlers'],
#  ['moonstone', 'monotones'],
#  ['tensor', 'sterno', 'nestor', 'tenors', 'stoner'],
#  ['entraps', 'pastern', 'napster', 'parents'],
#  ['nattier', 'nitrate'],
#  ['evelyn', 'evenly'],
#  ['ideas', 'sadie', 'aides', 'aside'],
#  ['spatter', 'patters'],
#  ['conservation', 'conversation'],
#  ['attic', 'tacit'],
#  ['alberto', 'latrobe'],
#  ['else', 'lees', 'eels'],
#  ['oust', 'outs'],
#  ['hairsbreadth', 'hairbreadths'],
#  ['akron', 'koran'],
#  ['sparsest', 'trespass'],
#  ["lapse's", "sepal's"],
#  ["oval's", "olav's"],
#  ['asps', 'saps', 'pass', 'spas'],
#  ['ayes', 'yeas', 'easy'],
#  ['mirage', 'margie', 'gamier'],
#  ['nets', 'tens', 'sent', 'nest'],
#  ['martian', 'martina'],
#  ["ideal's", "delia's"],
#  ['decor', 'cored', 'credo'],
#  ["list's", "slit's", "silt's"],
#  ['licks', 'slick'],
#  ["read's", "dear's", "dare's"],
#  ["brut's", "burt's"],
#  ['realization', 'rationalize'],
#  ['shoot', 'hoots', 'sooth'],
#  ["bean's", "bane's"],
#  ['vlasic', 'cavils', 'slavic'],
#  ['lag', 'gal'],
#  ["rub's", "bur's"],
#  ['hera', 'hare', 'rhea', 'hear'],
#  ['girdles', 'gliders'],
#  ["friend's", "finder's"],
#  ['alga', 'gala'],
#  ["tucson's", "tuscon's"],
#  ['crapes', 'recaps', 'capers', 'scrape', 'parsec'],
#  ['dos', 'sod'],
#  ['trailing', 'trialing'],
#  ['granted', 'dragnet'],
#  ["gazer's", "graze's"],
#  ['stressed', 'desserts'],
#  ['lorgnettes', 'longstreet'],
#  ['arden', 'andre', 'daren', 'nader'],
#  ['sara', 'saar'],
#  ["brooke's", "booker's"],
#  ["result's", "luster's", "lustre's", "rustle's", "ulster's"],
#  ['tokyo', 'kyoto'],
#  ['keels', 'sleek', 'leeks'],
#  ["lab's", "alb's"],
#  ["lineman's", "melanin's"],
#  ['iyar', 'airy'],
#  ['oldies', 'isolde', 'soiled'],
#  ['rues', 'ruse', 'user', 'sure'],
#  ['cloture', 'coulter'],
#  ['loan', 'nola'],
#  ["salve's", "slave's"],
#  ['pave', 'vape'],
#  ['potash', 'pathos'],
#  ['birther', 'rebirth'],
#  ["span's", "snap's"],
#  ['ethics', 'itches'],
#  ['gnarliest', 'integrals', 'triangles'],
#  ['harps', 'sharp'],
#  ['palsy', 'plays', 'splay'],
#  ['tientsin', 'tinniest'],
#  ['spree', 'speer', 'peers'],
#  ['spawn', 'pawns'],
#  ['capes', 'paces', 'space'],
#  ['townes', 'weston'],
#  ['usurper', 'pursuer'],
#  ["sid's", "dis's"],
#  ['outlays', 'layouts'],
#  ['ancienter', 'nectarine'],
#  ['mir', 'rim'],
#  ["titan's", "taint's"],
#  ["deification's", "edification's"],
#  ['details', 'dilates'],
#  ['based', 'beads'],
#  ["conrail's", "clarion's"],
#  ['relayed', 'layered'],
#  ['tors', 'rots', 'sort'],
#  ['altitudes', 'latitudes'],
#  ['carole', 'oracle'],
#  ['aloft', 'float'],
#  ['lois', 'soil', 'oils', 'silo', 'soli'],
#  ['tamps', 'stamp'],
#  ["tosca's", "coast's", "ascot's"],
#  ["aden's", "dena's", "edna's", "dane's", "dean's"],
#  ['slates', 'tassel', 'steals', 'stales'],
#  ['doe', 'ode'],
#  ["gum's", "mug's"],
#  ['raises', 'arises'],
#  ['orange', 'genaro'],
#  ['gradient', 'treading'],
#  ['breast', 'barest'],
#  ['melanin', 'lineman'],
#  ['singer', 'signer', 'resign', 'reigns', 'ingres'],
#  ['loans', 'sloan', 'salon'],
#  ['eat', 'ate', 'eta', 'tea'],
#  ["smile's", "selim's", "miles's", "slime's"],
#  ['accoutrements', 'accouterments'],
#  ['toppings', 'stopping'],
#  ['castillo', 'callisto'],
#  ['nabs', 'bans'],
#  ['sedna', 'danes', 'deans', 'andes', 'sedan', 'snead'],
#  ['flit', 'lift'],
#  ['relay', 'leary', 'early', 'layer'],
#  ['once', 'cone'],
#  ["jaunt's", "junta's"],
#  ['chisel', 'chiles'],
#  ['skit', 'kits'],
#  ['curate', 'acuter'],
#  ['ipecac', 'icecap'],
#  ["glare's", "large's", "elgar's", "lager's", "alger's"],
#  ['la', 'al'],
#  ['souped', 'pseudo'],
#  ['suitcase', 'sauciest'],
#  ["kline's", "klein's"],
#  ['riven', 'ervin'],
#  ["serial's", "israel's"],
#  ['tonier', 'orient'],
#  ['cackling', 'clacking'],
#  ["startup's", "upstart's"],
#  ['bales', 'basel', 'sable'],
#  ['snatched', 'stanched'],
#  ['ear', 'rae', 'era', 'are'],
#  ["tao's", "oat's"],
#  ["ural's", "raul's"],
#  ["ing's", "gin's"],
#  ['paths', 'staph'],
#  ['drag', 'grad'],
#  ["triage's", "gaiter's"],
#  ['how', 'who'],
#  ["amy's", "yam's", "may's"],
#  ["trippe's", "tipper's"],
#  ['detest', 'tested'],
#  ['fife', 'fief'],
#  ['sleepers', 'peerless'],
#  ['cassinos', 'caissons'],
#  ['pairs', 'parsi', 'paris'],
#  ['safer', 'fears', 'fares'],
#  ["melba's", "mable's", "mabel's", "blame's", "amble's"],
#  ['adler', 'alder'],
#  ['handcar', 'chandra'],
#  ['girt', 'grit', 'trig'],
#  ['pastes', 'spates'],
#  ['opt', 'pot', 'top'],
#  ['tarpons', 'patrons'],
#  ['caterers', 'terraces', 'retraces'],
#  ['bedlam', 'lambed', 'blamed', 'ambled'],
#  ['sirup', 'prius'],
#  ["recreant's", "terrance's"],
#  ['years', 'ayers'],
#  ['periled', 'replied'],
#  ['ratings', 'staring'],
#  ["galen's", "angle's", "angel's"],
#  ["act's", "cat's"],
#  ['sink', 'inks', 'skin'],
#  ['peppier', 'preppie'],
#  ['gina', 'agni', 'gain'],
#  ['blither', 'hilbert'],
#  ['ringside', 'residing', 'desiring'],
#  ["strait's", "artist's"],
#  ['insures', 'sunrise'],
#  ['truest', 'utters'],
#  ['trendier', 'interred'],
#  ["scat's", "acts's", "cast's"],
#  ['terran', 'errant', 'ranter'],
#  ['censers', 'screens'],
#  ["till's", "lilt's"],
#  ['transept', 'patterns'],
#  ['earthiest', 'heartiest'],
#  ['adroitly', 'idolatry', 'dilatory'],
#  ["specter's", "scepter's", "respect's"],
#  ['talent', 'latent'],
#  ['sleazier', 'realizes'],
#  ["craig's", "cigar's"],
#  ['parceled', 'replaced'],
#  ['thebes', 'behest'],
#  ['forensic', 'conifers'],
#  ['drapes', 'parsed', 'spread', 'padres', 'spared', 'rasped'],
#  ['menorahs', 'horseman'],
#  ['nations', 'anoints'],
#  ['cattily', 'tacitly'],
#  ['demurring', 'murdering'],
#  ["astor's", "sarto's", "roast's"],
#  ['weddell', 'dwelled'],
#  ['negroid', 'ignored', 'eroding', 'redoing'],
#  ['sera', 'sear', 'ares', 'eras', 'ears'],
#  ['mayors', 'morays'],
#  ['amour', 'mauro'],
#  ["cold's", "clod's"],
#  ['rousing', 'souring'],
#  ["tamra's", "marat's", "marta's"],
#  ['rereads', 'readers'],
#  ["odin's", "dion's", "dino's"],
#  ['lolcat', 'tlaloc'],
#  ['learnt', 'rental', 'antler'],
#  ['sheol', 'holes'],
#  ['oodles', 'loosed', 'soloed'],
#  ['brute', 'rebut', 'tuber'],
#  ['ogles', 'loges'],
#  ['mariadb', 'barmaid'],
#  ['ogre', 'ergo', 'roeg', 'gore'],
#  ['fora', 'afro'],
#  ['saviour', 'various'],
#  ['dora', 'road'],
#  ['beets', 'beset'],
#  ['latrines', 'entrails'],
#  ['slough', 'ghouls'],
#  ['fro', 'for'],
#  ['arms', 'mars', 'rams'],
#  ["prod's", "drop's"],
#  ['student', 'stunted'],
#  ['mired', 'rimed', 'dimer'],
#  ['marcy', 'camry'],
#  ['reality', 'irately'],
#  ['schematics', 'catechisms'],
#  ['speck', 'pecks'],
#  ['slowed', 'dowels'],
#  ["maul's", "alum's"],
#  ["gallo's", "algol's"],
#  ['root', 'oort'],
#  ['fried', 'fired'],
#  ['maroon', 'romano'],
#  ['magnate', 'magenta'],
#  ['browse', 'bowers'],
#  ['sapporo', 'apropos'],
#  ['void', 'ovid'],
#  ['keri', 'erik'],
#  ["sprite's", "stripe's", "priest's"],
#  ['hardy', 'hydra'],
#  ['spilt', 'split'],
#  ["oriental's", "relation's"],
#  ['pelts', 'slept', 'spelt'],
#  ['interim', 'termini', 'mintier'],
#  ["oscillation's", "colonialist's"],
#  ["pogo's", "goop's"],
#  ['depraved', 'pervaded'],
#  ['pones', 'epson', 'opens', 'peons'],
#  ["randell's", "darnell's"],
#  ['resort', 'sorter', 'roster', 'torres'],
#  ["garner's", "ranger's"],
#  ["lifer's", "rifle's", "flier's"],
#  ['speech', 'cheeps'],
#  ['quito', 'quoit'],
#  ['tonal', 'alton', 'talon'],
#  ['unison', 'unions'],
#  ['lister', 'liters'],
#  ['tesla', 'steal', 'slate', 'least', 'stael', 'stale', 'teals', 'tales'],
#  ['debugs', 'budges'],
#  ['repents', 'present', 'serpent'],
#  ["ismael's", "melisa's"],
#  ['skyed', 'dykes'],
#  ["warren's", "warner's"],
#  ['converge', 'congreve'],
#  ['keens', 'knees'],
#  ["elbow's", "bowel's"],
#  ['seams', 'mesas', 'sames'],
#  ['erratic', 'cartier'],
#  ['recheck', 'checker'],
#  ['upset', 'setup'],
#  ["viewer's", "review's"],
#  ['leno', 'lone', 'leon', 'noel', 'olen'],
#  ['sectors', 'corsets', 'escorts'],
#  ["bernanke's", "banneker's"],
#  ["chum's", "much's"],
#  ['heartier', 'earthier'],
#  ['sounder', 'resound'],
#  ["mores's", "morse's"],
#  ["dora's", "road's"],
#  ['threads', 'hardest', 'trashed', 'hatreds', 'dearths'],
#  ['tinned', 'indent', 'dentin', 'intend'],
#  ['bake', 'beak'],
#  ['boner', 'borne'],
#  ["lin's", "nil's"],
#  ['fauns', 'snafu'],
#  ["rapine's", "panier's", "napier's"],
#  ['agar', 'raga', 'agra'],
#  ['hobs', 'bosh'],
#  ["spat's", "past's"],
#  ["berle's", "rebel's"],
#  ['elise', 'elsie'],
#  ['demeter', 'metered'],
#  ['tokes', 'stoke'],
#  ['nieves', 'envies'],
#  ['coeds', 'codes'],
#  ['infringed', 'friending'],
#  ['scalloping', 'collapsing'],
#  ['carmella', 'marcella'],
#  ['timbres', 'timbers'],
#  ['trellis', 'stiller', 'tillers'],
#  ['keening', 'kneeing'],
#  ['chap', 'caph'],
#  ['gates', 'stage'],
#  ['tankers', 'rankest'],
#  ["kris's", "risk's"],
#  ['colones', 'console'],
#  ['mundane', 'unnamed'],
#  ['topically', 'optically'],
#  ['easter', 'teresa', 'eaters', 'teaser'],
#  ['wolfs', 'flows', 'fowls'],
#  ['liars', 'rails', 'liras', 'lairs'],
#  ['beseech', 'beeches'],
#  ['article', 'recital'],
#  ['coed', 'code'],
#  ['crimson', 'microns'],
#  ['dawns', 'wands'],
#  ['charon', 'anchor'],
#  ['puree', 'rupee'],
#  ['shad', 'dash'],
#  ["amaru's", "maura's"],
#  ['despair', 'aspired', 'diapers', 'praised'],
#  ["nassau's", "susana's"],
#  ["ruse's", "user's"],
#  ['pediatrics', 'patricides'],
#  ["armenian's", "annmarie's", "marianne's"],
#  ['goths', 'ghost'],
#  ["osman's", "mason's"],
#  ['finer', 'infer'],
#  ['cheaters', 'hectares', 'teachers'],
#  ['erasmus', 'masseur'],
#  ["solo's", "oslo's"],
#  ['replay', 'parley', 'player', 'pearly'],
#  ["ginkgo's", "gingko's"],
#  ['stickpin', 'nitpicks'],
#  ["lien's", "neil's", "nile's", "line's"],
#  ['lenore', 'lorene'],
#  ["searcher's", "research's"],
#  ['palsying', 'splaying'],
#  ['saxon', 'axons'],
#  ['chasers', 'crashes'],
#  ['saw', 'aws', 'was'],
#  ['retire', 'terrie'],
#  ['genera', 'enrage'],
#  ['polythene', 'telephony'],
#  ['wiser', 'weirs', 'wires'],
#  ['sergeants', 'estranges', 'greatness'],
#  ["dingo's", "doing's"],
#  ['orate', 'erato'],
#  ['chester', 'retches', 'etchers'],
#  ["wendi's", "edwin's"],
#  ['marrieds', 'admirers'],
#  ['need', 'eden'],
#  ['buster', 'brutes', 'rebuts', 'tubers'],
#  ['resold', 'solder'],
#  ['parroted', 'prorated', 'teardrop', 'predator'],
#  ['goop', 'pogo'],
#  ['bombing', 'mobbing'],
#  ['node', 'deon', 'done'],
#  ['twits', 'twist'],
#  ['adeline', 'aliened'],
#  ['sports', 'strops'],
#  ['wonder', 'downer'],
#  ["bristle's", "blister's"],
#  ['maura', 'amaru'],
#  ["robyn's", "bryon's", "byron's"],
#  ['sheik', 'hikes'],
#  ['pits', 'spit', 'tips'],
#  ["crooner's", "coroner's"],
#  ['spam', 'amps', 'maps'],
#  ['olga', 'goal'],
#  ['reinterpret', 'interpreter'],
#  ['caduceus', 'caucused'],
#  ["bates's", "beast's"],
#  ['harkens', 'hankers'],
#  ['calmer', 'marcel'],
#  ['fillers', 'refills'],
#  ['percale', 'replace'],
#  ['drab', 'brad', 'bard'],
#  ["senate's", "sateen's"],
#  ['enable', 'baleen'],
#  ['sander', 'snared', 'andres'],
#  ['equip', 'pique'],
#  ['film', 'milf'],
#  ["gather's", "gareth's"],
#  ['patsies', 'pasties'],
#  ['electra', 'treacle'],
#  ['spinal', 'plains'],
#  ['tins', 'nits', 'snit'],
#  ["lauri's", "luria's"],
#  ['laity', 'italy'],
#  ['sheeting', 'seething'],
#  ['cronies', 'ericson'],
#  ['elates', 'estela', 'teasel'],
#  ["leak's", "kale's", "lake's"],
#  ['smartened', 'tradesmen'],
#  ["urination's", "ruination's"],
#  ["cholera's", "chorale's"],
#  ['laze', 'zeal'],
#  ['stewart', 'swatter'],
#  ['yaws', 'ways', 'sway'],
#  ["beater's", "rebate's"],
#  ['atreus', 'seurat'],
#  ["petersen's", "pretense's"],
#  ['mechanics', 'mischance'],
#  ["wear's", "ware's"],
#  ['carbides', 'ascribed'],
#  ["parcel's", "placer's", "carpel's"],
#  ["trina's", "train's"],
#  ["rule's", "lure's"],
#  ['velma', 'melva'],
#  ['tooled', 'toledo', 'looted'],
#  ["lana's", "alan's"],
#  ['theologians', 'anthologies'],
#  ['sims', 'miss', 'isms'],
#  ['tellers', 'retells'],
#  ['grounded', 'underdog'],
#  ['angled', 'dangle', 'glenda'],
#  ['cackled', 'clacked'],
#  ['duelist', 'dilutes'],
#  ["shaw's", "wash's"],
#  ['recipes', 'precise', 'pierces'],
#  ['name', 'amen', 'mean', 'mane'],
#  ["daze's", "adze's"],
#  ["leap's", "pale's", "plea's", "peal's"],
#  ['erect', 'crete'],
#  ['mesa', 'seam', 'same'],
#  ['intrude', 'untried'],
#  ['ypres', 'preys', 'pyres'],
#  ['lapsing', 'palings', 'sapling'],
#  ['divan', 'dvina', 'viand'],
#  ['higgins', 'sighing'],
#  ["morn's", "norm's"],
#  ['stow', 'tows', 'twos'],
#  ['dire', 'ride', 'reid'],
#  ["crepe's", "creep's"],
#  ['reforests', 'foresters'],
#  ['tooling', 'looting'],
#  ['domes', 'modes', 'demos'],
#  ['bordello', 'doorbell'],
#  ["hectare's", "teacher's", "cheater's"],
#  ['distaste', 'staidest'],
#  ['norma', 'moran', 'ramon', 'manor', 'roman'],
#  ['issue', 'susie'],
#  ['theatre', 'theater'],
#  ['marbles', 'rambles'],
#  ['intenser', 'internes'],
#  ['curies', 'cruise'],
#  ['impresses', 'premisses'],
#  ["keats's", "stake's", "skate's", "steak's"],
#  ["loge's", "ogle's", "lego's"],
#  ['roomer', 'romero'],
#  ['ecru', 'cure'],
#  ['desert', 'rested', 'deters'],
#  ['lats', 'slat', 'last', 'salt'],
#  ["bus's", "sub's", "ubs's"],
#  ['alert', 'alter', 'later'],
#  ['hinges', 'neighs'],
#  ['pram', 'ramp'],
#  ['sidearms', 'misreads'],
#  ['coordinate', 'decoration'],
#  ['pearled', 'pleader'],
#  ['depend', 'pended'],
#  ['simplest', 'misspelt'],
#  ['settlers', 'trestles'],
#  ['xe', 'ex'],
#  ["bounder's", "rebound's"],
#  ['sahel', 'shale', 'heals', 'leash', 'hales'],
#  ['menials', 'seminal'],
#  ['laura', 'aural'],
#  ['dikes', 'skied'],
#  ['precipitate', 'peripatetic'],
#  ['mindless', 'mildness'],
#  ["milestone's", "limestone's"],
#  ['lab', 'alb'],
#  ['lifers', 'fliers', 'rifles'],
#  ['bangor', 'brogan'],
#  ['setters', 'testers', 'streets', 'tersest'],
#  ["lhotse's", "hostel's"],
#  ['elastics', 'scaliest', 'alcestis'],
#  ['craven', 'cavern'],
#  ['vaster', 'averts', 'starve'],
#  ['meeting', 'teeming'],
#  ["peel's", "pele's"],
#  ['sower', 'swore', 'worse'],
#  ['orgies', 'sergio'],
#  ['cat', 'act'],
#  ["won's", "now's"],
#  ['tilts', 'stilt'],
#  ['reprise', 'respire'],
#  ["least's", "steal's", "slate's", "tesla's", "stael's"],
#  ["arno's", "nora's", "aron's", "oran's", "roan's"],
#  ['orval', 'valor'],
#  ['trifling', 'flirting'],
#  ['austin', 'unitas'],
#  ['apter', 'prate', 'taper', 'petra'],
#  ['coexist', 'exotics'],
#  ["body's", "boyd's"],
#  ['halts', 'laths', 'shalt'],
#  ['lenny', 'lynne'],
#  ['drive', 'verdi', 'diver'],
#  ['tenon', 'tonne'],
#  ['rices', 'cries'],
#  ["anvil's", "alvin's"],
#  ['nerdiest', 'dniester', 'resident', 'inserted', 'trendies'],
#  ['crashing', 'chagrins'],
#  ["dunbar's", "durban's"],
#  ['macho', 'mocha'],
#  ['deep', 'peed'],
#  ["sonar's", "arson's"],
#  ['saddle', 'addles'],
#  ['dungaree', 'underage'],
#  ['item', 'emit', 'mite', 'time'],
#  ['blest', 'belts'],
#  ['lank', 'klan'],
#  ['keystone', 'keynotes'],
#  ["emo's", "moe's"],
#  ['detour', 'toured', 'routed'],
#  ['recasting', 'caterings'],
#  ['bittern', 'britten'],
#  ['stewed', 'tweeds'],
#  ['otter', 'torte'],
#  ['velours', 'louvers'],
#  ["ila's", "ali's"],
#  ["nivea's", "evian's"],
#  ['mat', 'tam'],
#  ['feints', 'infest', 'finest'],
#  ["dorian's", "inroad's"],
#  ['niggas', 'agings'],
#  ['replacing', 'parceling'],
#  ['flowed', 'wolfed', 'fowled'],
#  ['roasts', 'assort'],
#  ['tartan', 'rattan'],
#  ['daley', 'delay'],
#  ['colonialist', 'oscillation'],
#  ["aery's", "year's"],
#  ['forge', 'gofer'],
#  ['zeus', 'suez'],
#  ['earbud', 'dauber'],
#  ['costar', 'croats', 'actors', 'scrota', 'castro', 'castor'],
#  ['wonders', 'downers'],
#  ["nobel's", "noble's"],
#  ['flemish', 'himself'],
#  ["sadie's", "aside's"],
#  ['marianne', 'annmarie', 'armenian'],
#  ['compile', 'polemic'],
#  ['hustling', 'sunlight'],
#  ['sakai', 'kasai'],
#  ['ebony', 'boney'],
#  ['streaming', 'mastering', 'emigrants'],
#  ["leila's", "lelia's", "allie's"],
#  ['route', 'outer'],
#  ['wings', 'swing'],
#  ['wolves', 'vowels'],
#  ['sating', 'giants'],
#  ['able', 'abel', 'bela', 'bale', 'elba'],
#  ["girth's", "right's"],
#  ['turnover', 'overturn'],
#  ['tore', 'rote'],
#  ['empires', 'premise'],
#  ['triteness', 'interests'],
#  ["shan't", "hasn't"],
#  ['disperse', 'presides'],
#  ['sifter', 'strife', 'rifest', 'refits'],
#  ["wrap's", "warp's"],
#  ['lobe', 'bole'],
#  ['ardent', 'ranted'],
#  ["scalp's", "clasp's"],
#  ['moaned', 'daemon'],
#  ['ruble', 'bluer'],
#  ["asp's", "sap's", "spa's"],
#  ['decimate', 'medicate'],
#  ['worker', 'rework'],
#  ['lump', 'plum'],
#  ['elapses', 'pleases'],
#  ['mona', 'oman', 'moan'],
#  ["elma's", "male's", "meal's", "elam's", "lame's"],
#  ['answers', 'rawness'],
#  ['insatiable', 'banalities'],
#  ['perseid', 'preside'],
#  ["pane's", "nape's", "pena's"],
#  ["outlay's", "layout's"],
#  ['taunted', 'attuned'],
#  ['mable', 'blame', 'mabel', 'melba', 'amble'],
#  ['miters', 'merits', 'mister', 'remits', 'timers'],
#  ['many', 'myna'],
#  ['corey', 'royce', 'coyer'],
#  ['armfuls', 'armsful'],
#  ['anvils', 'silvan'],
#  ['nerves', 'severn'],
#  ['andrews', 'wardens', 'wanders'],
#  ["statement's", "testament's"],
#  ['umps', 'sump'],
#  ['conrad', 'candor', 'dacron'],
#  ['loudest', 'tousled'],
#  ["contrail's", "cilantro's"],
#  ['sallow', 'allows'],
#  ['scalene', 'cleanse'],
#  ["tran's", "rant's"],
#  ['now', 'own', 'won'],
#  ['cupola', 'copula'],
#  ["ram's", "arm's", "mar's"],
#  ["raw's", "war's"],
#  ['newt', 'went'],
#  ["incest's", "insect's"],
#  ['klein', 'liken', 'kline'],
#  ['complies', 'compiles', 'polemics'],
#  ["megaton's", "montage's", "magneto's"],
#  ['agree', 'eager'],
#  ['restarts', 'starters'],
#  ['stint', 'tints'],
#  ["saddam's", "addams's"],
#  ['taoisms', 'maoists'],
#  ["altitude's", "latitude's"],
#  ['inkling', 'kilning', 'linking'],
#  ['punters', 'punster'],
#  ["pan's", "nap's"],
#  ['rares', 'serra', 'rears'],
#  ['oars', 'rosa', 'soar'],
#  ['dot', 'tod'],
#  ['splendid', 'spindled'],
#  ["mervin's", "vermin's"],
#  ["velcro's", "clover's"],
#  ['basin', 'sabin'],
#  ["car's", "arc's", "rca's"],
#  ['maine', 'anime'],
#  ['smash', 'shams'],
#  ['stances', 'ascents'],
#  ["ante's", "etna's", "nate's"],
#  ["id's", "di's"],
#  ['files', 'flies'],
#  ["vial's", "vila's"],
#  ['developers', 'redevelops'],
#  ['hocking', 'choking'],
#  ['seabird', 'braised', 'sidebar'],
#  ['peron', 'prone'],
#  ['tritest', 'titters'],
#  ['quieter', 'requite'],
#  ['brigades', 'abridges'],
#  ['folgers', 'golfers'],
#  ['singing', 'signing'],
#  ['rival', 'viral'],
#  ['canopying', 'poignancy'],
#  ['huntsman', 'manhunts'],
#  ['stabling', 'blasting'],
#  ['mit', 'tim'],
#  ['caring', 'arcing', 'racing'],
#  ["soil's", "lois's", "silo's"],
#  ['indices', 'incised'],
#  ['lumps', 'slump', 'plums'],
#  ["lesion's", "insole's"],
#  ['mores', 'romes', 'morse'],
#  ["charisma's", "archaism's"],
#  ['proudest', 'postured', 'sprouted'],
#  ['shotguns', 'gunshots'],
#  ['alyce', 'lacey'],
#  ['ugliest', 'gluiest'],
#  ['rode', 'doer', 'oder', 'redo'],
#  ['knits', 'stink'],
#  ['toed', 'dote'],
#  ['ilks', 'silk'],
#  ['tense', 'teens'],
#  ['warehouses', 'housewares'],
#  ['rising', 'siring'],
#  ['cowers', 'escrow'],
#  ["lena's", "lane's", "lean's", "neal's"],
#  ["over's", "rove's"],
#  ['veriest', 'restive'],
#  ['si', 'is'],
#  ['albion', 'albino'],
#  ["labrador's", "larboard's"],
#  ['inclosure', 'cornelius'],
#  ['raves', 'saver', 'avers'],
#  ['cassock', 'cossack'],
#  ['dines', 'snide', 'denis'],
#  ['astir', 'stair', 'sitar'],
#  ['rhodes', 'hordes', 'horsed', 'shored'],
#  ['fortieths', 'frothiest'],
#  ['dignifies', 'signified'],
#  ["palmer's", "marple's"],
#  ['delivers', 'silvered', 'slivered'],
#  ['stare', 'taser', 'tears', 'tares', 'rates', 'aster'],
#  ['scrapes', 'parsecs'],
#  ["manual's", "alumna's"],
#  ['atolls', 'allots'],
#  ['restoring', 'resorting'],
#  ["tale's", "teal's", "leta's"],
#  ['grudging', 'drugging'],
#  ['continued', 'unnoticed'],
#  ['infests', 'fitness'],
#  ['gracie', 'cagier'],
#  ['renters', 'sterner'],
#  ["harlem's", "mahler's"],
#  ['dorset', 'sorted', 'stored', 'strode'],
#  ["tardiness's", "streisand's"],
#  ['tolyatti', 'totality'],
#  ['calks', 'lacks', 'slack'],
#  ['leif', 'life', 'lief', 'file'],
#  ['logarithms', 'algorithms'],
#  ['sombrely', 'somberly'],
#  ["moray's", "mayor's"],
#  ['smarter', 'armrest'],
#  ['retweets', 'tweeters'],
#  ["sorbet's", "osbert's", "strobe's"],
#  ["nit's", "tin's", "isn't"],
#  ["eden's", "need's"],
#  ['voided', 'devoid'],
#  ['concerting', 'concreting'],
#  ['fondus', 'founds'],
#  ['initiated', 'dietitian'],
#  ['redhead', 'adhered'],
#  ['loop', 'pool', 'polo'],
#  ['shook', 'hooks'],
#  ['novels', 'sloven'],
#  ["plane's", "panel's", "nepal's"],
#  ["diver's", "verdi's", "drive's"],
#  ['prince', 'pincer'],
#  ["proteus's", "posture's"],
#  ["atria's", "atari's", "tiara's"],
#  ["kristen's", "stinker's", "kirsten's"],
#  ['peek', 'keep'],
#  ['riel', 'rile', 'lire'],
#  ['sheba', 'hbase'],
#  ['ella', 'lela'],
#  ['certifications', 'rectifications'],
#  ['orientating', 'integration'],
#  ['nomad', 'damon'],
#  ["heron's", "horne's", "rhone's"],
#  ['burl', 'blur'],
#  ['stead', 'sated', 'dates'],
#  ['girts', 'grits', 'grist'],
#  ['puns', 'spun'],
#  ['incest', 'nicest', 'insect'],
#  ["soto's", "soot's"],
#  ['caliper', 'replica'],
#  ['nested', 'tensed'],
#  ['star', 'arts', 'tsar', 'tars', 'rats'],
#  ['stoker', 'stroke'],
#  ['decals', 'scaled'],
#  ['potions', 'options'],
#  ["lorre's", "errol's"],
#  ['ticks', 'stick'],
#  ['regina', 'regain'],
#  ['pasteur', 'pasture'],
#  ['printings', 'sprinting'],
#  ['pinking', 'kingpin'],
#  ['demoniac', 'comedian'],
#  ['altair', 'lariat'],
#  ["argon's", "groan's", "organ's"],
#  ["singer's", "signer's", "ingres's"],
#  ['toiler', 'loiter'],
#  ["resident's", "dniester's"],
#  ["anime's", "maine's"],
#  ['despot', 'posted', 'depots'],
#  ['york', 'kory'],
#  ['wormwood', 'woodworm'],
#  ["verna's", "raven's"],
#  ['dingy', 'dying'],
#  ["irtish's", "tishri's"],
#  ['bidet', 'debit'],
#  ['resumption', 'importunes'],
#  ['masher', 'harems'],
#  ['nosed', 'nodes'],
#  ['canter', 'recant', 'nectar', 'trance', 'cretan'],
#  ['satanism', 'mantissa'],
#  ['martel', 'armlet'],
#  ['stabled', 'blasted', 'baldest'],
#  ['manuela', 'alumnae'],
#  ["romance's", "cameron's"],
#  ['peters', 'pester', 'preset'],
#  ["gardenia's", "drainage's"],
#  ['demotion', 'motioned'],
#  ['bushels', 'blushes'],
#  ['prigs', 'sprig', 'grips'],
#  ["alden's", "nelda's"],
#  ['usurpers', 'pursuers'],
#  ["pest's", "step's"],
#  ['alcindor', 'ironclad'],
#  ['titling', 'tlingit', 'tilting'],
#  ['turnovers', 'overturns'],
#  ['melded', 'meddle'],
#  ['corps', 'crops'],
#  ['reorgs', 'rogers'],
#  ['mercado', 'caromed', 'comrade'],
#  ['indenting', 'intending'],
#  ['sledging', 'geldings'],
#  ["nepali's", "alpine's"],
#  ["aisle's", "elias's", "elisa's"],
#  ['cinema', 'anemic'],
#  ['producer', 'procured'],
#  ['sliver', 'silver', 'livers'],
#  ['olsen', 'noels'],
#  ["kate's", "teak's", "take's"],
#  ["ella's", "lela's"],
#  ["elnora's", "lenora's", "elanor's", "loaner's", "lorena's"],
#  ['linkage', 'leaking'],
#  ['daniel', 'nailed', 'alined', 'denial'],
#  ['brawlers', 'warblers'],
#  ['tautest', 'statute'],
#  ['wired', 'weird', 'wider'],
#  ['noelle', 'leonel'],
#  ['meagan', 'manage'],
#  ["lewis's", "wiles's"],
#  ['flier', 'rifle', 'lifer'],
#  ['flees', 'feels'],
#  ['singers', 'signers', 'resigns', 'ingress'],
#  ['yemen', 'enemy'],
#  ['ankhs', 'shank', 'khans', 'hanks'],
#  ['robing', 'boring'],
#  ['earliest', 'ateliers'],
#  ['hates', 'heats', 'haste'],
#  ['seedier', 'desiree'],
#  ['disks', 'skids'],
#  ['supers', 'purses'],
#  ['tutsi', 'titus'],
#  ['stile', 'tiles', 'islet'],
#  ['overdose', 'overdoes'],
#  ['emanates', 'manatees'],
#  ['shouts', 'souths'],
#  ['logan', 'anglo', 'golan', 'along'],
#  ['feeling', 'fleeing'],
#  ['plugins', 'pulsing'],
#  ['sidney', 'disney'],
#  ['lattice', 'tactile'],
#  ['plaint', 'pliant'],
#  ['dallies', 'sallied'],
#  ['remake', 'kareem'],
#  ['staples', 'pastels'],
#  ['redis', 'rides', 'sired', 'dries'],
#  ['thing', 'night'],
#  ["bosnia's", "bonsai's"],
#  ['crochets', 'crotches'],
#  ['archie', 'achier'],
#  ["rethink's", "thinker's"],
#  ['enters', 'sterne', 'tenser', 'ernest', 'resent'],
#  ['transient', 'intranets'],
#  ['barley', 'bleary', 'barely'],
#  ['deform', 'formed'],
#  ["nigga's", "aging's"],
#  ["pinto's", "piton's", "point's"],
#  ["bangle's", "bengal's"],
#  ['rotates', 'rosetta', 'toaster'],
#  ['ac', 'ca'],
#  ['islams', 'missal'],
#  ['belgian', 'bengali', 'algenib'],
#  ['enfolds', 'fondles'],
#  ["prattle's", "platter's"],
#  ['hits', 'shit', 'this'],
#  ['flared', 'alfred'],
#  ["fern's", "nerf's"],
#  ['lots', 'slot', 'lost'],
#  ['slides', 'sidles'],
#  ['thor', 'roth'],
#  ["ubangi's", "bangui's"],
#  ['swearer', 'wearers'],
#  ["thermos's", "smother's"],
#  ["emusic's", "cesium's", "miscue's"],
#  ['ales', 'elsa', 'lesa', 'leas', 'sale', 'seal'],
#  ["cedar's", "cadre's"],
#  ["shaka's", "sakha's"],
#  ['grater', 'garret', 'garter'],
#  ['mel', 'elm'],
#  ['delights', 'slighted'],
#  ['boer', 'bore', 'ebro', 'robe'],
#  ['configures', 'refocusing'],
#  ["pasty's", "patsy's"],
#  ['nashua', 'shauna'],
#  ["tonga's", "tango's"],
#  ['spate', 'paste', 'tapes', 'pates', 'septa'],
#  ["okra's", "karo's"],
#  ['touts', 'stout'],
#  ['devise', 'sieved'],
#  ['rapiers', 'repairs', 'raspier', 'parries'],
#  ['arline', 'linear'],
#  ["marciano's", "macaroni's"],
#  ["stoner's", "nestor's", "sterno's"],
#  ['repeals', 'relapse'],
#  ["sprout's", "stupor's", "proust's"],
#  ['grease', 'agrees'],
#  ['deposit', 'posited', 'topside', 'dopiest'],
#  ['bengal', 'bangle'],
#  ["team's", "meat's", "mate's"],
#  ['acrostic', 'socratic'],
#  ['overacts', 'overcast'],
#  ["canto's", "acton's"],
#  ['sourest', 'ousters'],
#  ['inonu', 'union'],
#  ['fended', 'defend'],
#  ['mailed', 'medial', 'imelda'],
#  ['brno', 'born'],
#  ['secretion', 'erections'],
#  ['lake', 'kale', 'leak'],
#  ['gaps', 'gasp'],
#  ["lima's", "mail's", "mali's"],
#  ["awl's", "law's"],
#  ['gallo', 'algol'],
#  ['vessel', 'selves'],
#  ['shear', 'rheas', 'hares', 'share', 'hears'],
#  ['nemesis', 'siemens'],
#  ["salon's", "sloan's"],
#  ["caisson's", "cassino's"],
#  ['stupor', 'sprout', 'proust'],
#  ['imams', 'maims'],
#  ['sprayer', 'prayers'],
#  ['predominates', 'impersonated'],
#  ['putin', 'input'],
#  ['oval', 'olav'],
#  ['tweeter', 'retweet'],
#  ['lin', 'nil'],
#  ['whale', 'wheal'],
#  ['sellouts', 'outsells'],
#  ["brno's", "born's"],
#  ['reveling', 'levering'],
#  ['gurgles', 'slugger'],
#  ['breath', 'bertha', 'bather'],
#  ['sub', 'ubs', 'bus'],
#  ['rape', 'pare', 'pear', 'earp', 'reap'],
#  ['bast', 'bats', 'stab', 'tabs'],
#  ['rinse', 'risen', 'reins', 'siren', 'resin'],
#  ['drooled', 'doodler'],
#  ['hassles', 'slashes'],
#  ["player's", "parley's", "replay's"],
#  ['flesh', 'shelf'],
#  ['envied', 'veined', 'endive'],
#  ['undated', 'daunted'],
#  ['plead', 'pedal', 'paled'],
#  ['uterus', 'suture'],
#  ['field', 'fidel', 'filed', 'flied'],
#  ['carlo', 'coral', 'carol'],
#  ['manley', 'laymen', 'meanly', 'namely'],
#  ["alba's", "baal's"],
#  ["timer's", "miter's", "merit's"],
#  ['cleaners', 'cleanser'],
#  ['tyros', 'troys', 'story'],
#  ['snatch', 'stanch', 'chants'],
#  ['glossing', 'goslings'],
#  ['boast', 'boats'],
#  ['deal', 'dale', 'lade', 'lead', 'leda'],
#  ['lacking', 'calking'],
#  ['porter', 'report'],
#  ['here', 'rhee'],
#  ['costing', 'gnostic'],
#  ['open', 'nope', 'peon', 'pone'],
#  ["so's", "os's"],
#  ['theresa', 'reheats', 'heaters'],
#  ['missile', 'similes'],
#  ['dirge', 'ridge'],
#  ["martel's", "armlet's"],
#  ['urinals', 'insular'],
#  ['flea', 'leaf'],
#  ["slut's", "lust's"],
#  ['stonier', 'orients'],
#  ['starch', 'charts'],
#  ['misprint', 'imprints'],
#  ['skirting', 'striking'],
#  ['shaw', 'haws', 'wash'],
#  ['neruda', 'unread'],
#  ['selection', 'elections'],
#  ['gape', 'page'],
#  ['blogs', 'globs'],
#  ['samson', 'masons'],
#  ['alba', 'baal'],
#  ['laden', 'alden', 'nelda'],
#  ['dales', 'leads', 'lades', 'deals'],
#  ['sat', 'ats'],
#  ['shower', 'whores'],
#  ['tracer', 'carter', 'crater'],
#  ['colonialists', 'oscillations'],
#  ['lime', 'emil', 'mile'],
#  ['purims', 'purism'],
#  ["wriggle's", "wiggler's"],
#  ["abode's", "adobe's"],
#  ['arc', 'rca', 'car'],
#  ['ashore', 'hoarse'],
#  ["suture's", "uterus's"],
#  ['sued', 'used', 'duse', 'dues'],
#  ["venetian's", "aventine's"],
#  ['crooner', 'coroner'],
#  ...]

# %% [markdown]
# **Exercise 8:**
# Find the longest word with at least one anagram. Suggestion: use the `key` argument of `sort` or `sorted` ([see here](https://stackoverflow.com/questions/8966538/syntax-behind-sortedkey-lambda)).

# %%
def better_function(set_of_str):
    dictionary = {}
    return_list = []
    for word in set_of_str:
        sorted_word = ''.join(sorted(word))
        if sorted_word not in dictionary:
            dictionary[sorted_word] = [word]
        else:
            dictionary[sorted_word].append(word)

    #remove words with no anagrams
    for k, v in dictionary.items():
            if len(v)>=2:
                return_list.append(v)

#find the longest word
    a = 0
    for k in return_list:
      if len(k[1]) > a:
        longest = k
        a = len(k[1])

    return longest

better_function(word_list)
# Out:
# ["impressiveness's", "permissiveness's"]

# %% [markdown]
# **Exercise 9:**
# Find the largest list of words that are anagrams of each other.

# %%
def better_function(set_of_str):
    dictionary = {}
    return_list = []
    for word in set_of_str:
        sorted_word = ''.join(sorted(word))
        if sorted_word not in dictionary:
            dictionary[sorted_word] = [word]
        else:
            dictionary[sorted_word].append(word)

#remove words with no anagrams
    for k, v in dictionary.items():
            if len(v)>=2:
                return_list.append(v)

#find the word with most anagrams
    length_of_longest = 0
    for set_of_anagrams in return_list:
        if len(set_of_anagrams) > length_of_longest:
            length_of_longest = len(set_of_anagrams)
            most_anagrams = set_of_anagrams

    return most_anagrams

better_function(word_list)
# Out:
# ['tesla', 'steal', 'slate', 'least', 'stael', 'stale', 'teals', 'tales']

# %% [markdown]
# **Exercise 10:**
# Write a function that takes an integer `word_length` and finds the longest list of words with the given length that are anagrams of each other.

# %%
def anagram_length(word_length):
    dictionary = {}
    return_list = []
    for word in word_list:
        sorted_word = ''.join(sorted(word))
        if sorted_word not in dictionary:
            dictionary[sorted_word] = [word]
        else:
            dictionary[sorted_word].append(word)

#remove words with no anagrams
    for k, v in dictionary.items():
            if len(v)>=2:
                return_list.append(v)

#find the word with most anagrams and length of word_length
    length_of_longest = 0
    for set_of_anagrams in return_list:
        if len(set_of_anagrams) > length_of_longest and len(set_of_anagrams[1]) == word_length:
            length_of_longest = len(set_of_anagrams)
            most_anagrams = set_of_anagrams
            return most_anagrams

# %%
anagram_length(15)
# Out:
# ["rectification's", "certification's"]

# %% [markdown]
# **Exercise 11:**
# At this point we have a data structure that contains lists of words that are anagrams, but we have not actually enumerated all pairs.
# Write a function that takes `anagram_map` and returns a list of all anagram pairs.
# How many are there?

# %%
def anagram_enumerated():
    dictionary = {}
    return_list = []
    for word in word_list:
        sorted_word = ''.join(sorted(word))
        if sorted_word not in dictionary:
            dictionary[sorted_word] = [word]
        else:
            dictionary[sorted_word].append(word)

#remove words with no anagrams
    for k, v in dictionary.items():
            if len(v)>=2:
                return_list.append(v)
    print(f'There are {len(return_list)} sets of anagrams')
    return return_list

# %%
anagram_enumerated()
# Out:
# There are 5872 sets of anagrams
# [["rolando's", "orlando's"],
#  ['morals', 'molars'],
#  ['programers', 'reprograms'],
#  ['rate', 'tare', 'tear'],
#  ['escher', 'cheers'],
#  ['wraps', 'warps'],
#  ['streams', 'masters'],
#  ['ashed', 'shade', 'heads', 'hades'],
#  ['elides', 'diesel'],
#  ['junta', 'jaunt'],
#  ['vernal', 'lavern'],
#  ['leeriest', 'steelier'],
#  ['heptagons', 'pathogens'],
#  ["erse's", "seer's"],
#  ['snoop', 'spoon'],
#  ['refill', 'filler'],
#  ['chore', 'ocher', 'roche', 'ochre'],
#  ['rescinds', 'discerns'],
#  ["khan's", "hank's", "ankh's"],
#  ['cavalries', 'cavaliers'],
#  ['atom', 'moat'],
#  ['benton', 'bonnet'],
#  ['canny', 'nancy'],
#  ["lisp's", "slip's"],
#  ["diary's", "dairy's"],
#  ['weirdos', 'dowries', 'rowdies'],
#  ['slither', 'hitlers'],
#  ['moonstone', 'monotones'],
#  ['tensor', 'sterno', 'nestor', 'tenors', 'stoner'],
#  ['entraps', 'pastern', 'napster', 'parents'],
#  ['nattier', 'nitrate'],
#  ['evelyn', 'evenly'],
#  ['ideas', 'sadie', 'aides', 'aside'],
#  ['spatter', 'patters'],
#  ['conservation', 'conversation'],
#  ['attic', 'tacit'],
#  ['alberto', 'latrobe'],
#  ['else', 'lees', 'eels'],
#  ['oust', 'outs'],
#  ['hairsbreadth', 'hairbreadths'],
#  ['akron', 'koran'],
#  ['sparsest', 'trespass'],
#  ["lapse's", "sepal's"],
#  ["oval's", "olav's"],
#  ['asps', 'saps', 'pass', 'spas'],
#  ['ayes', 'yeas', 'easy'],
#  ['mirage', 'margie', 'gamier'],
#  ['nets', 'tens', 'sent', 'nest'],
#  ['martian', 'martina'],
#  ["ideal's", "delia's"],
#  ['decor', 'cored', 'credo'],
#  ["list's", "slit's", "silt's"],
#  ['licks', 'slick'],
#  ["read's", "dear's", "dare's"],
#  ["brut's", "burt's"],
#  ['realization', 'rationalize'],
#  ['shoot', 'hoots', 'sooth'],
#  ["bean's", "bane's"],
#  ['vlasic', 'cavils', 'slavic'],
#  ['lag', 'gal'],
#  ["rub's", "bur's"],
#  ['hera', 'hare', 'rhea', 'hear'],
#  ['girdles', 'gliders'],
#  ["friend's", "finder's"],
#  ['alga', 'gala'],
#  ["tucson's", "tuscon's"],
#  ['crapes', 'recaps', 'capers', 'scrape', 'parsec'],
#  ['dos', 'sod'],
#  ['trailing', 'trialing'],
#  ['granted', 'dragnet'],
#  ["gazer's", "graze's"],
#  ['stressed', 'desserts'],
#  ['lorgnettes', 'longstreet'],
#  ['arden', 'andre', 'daren', 'nader'],
#  ['sara', 'saar'],
#  ["brooke's", "booker's"],
#  ["result's", "luster's", "lustre's", "rustle's", "ulster's"],
#  ['tokyo', 'kyoto'],
#  ['keels', 'sleek', 'leeks'],
#  ["lab's", "alb's"],
#  ["lineman's", "melanin's"],
#  ['iyar', 'airy'],
#  ['oldies', 'isolde', 'soiled'],
#  ['rues', 'ruse', 'user', 'sure'],
#  ['cloture', 'coulter'],
#  ['loan', 'nola'],
#  ["salve's", "slave's"],
#  ['pave', 'vape'],
#  ['potash', 'pathos'],
#  ['birther', 'rebirth'],
#  ["span's", "snap's"],
#  ['ethics', 'itches'],
#  ['gnarliest', 'integrals', 'triangles'],
#  ['harps', 'sharp'],
#  ['palsy', 'plays', 'splay'],
#  ['tientsin', 'tinniest'],
#  ['spree', 'speer', 'peers'],
#  ['spawn', 'pawns'],
#  ['capes', 'paces', 'space'],
#  ['townes', 'weston'],
#  ['usurper', 'pursuer'],
#  ["sid's", "dis's"],
#  ['outlays', 'layouts'],
#  ['ancienter', 'nectarine'],
#  ['mir', 'rim'],
#  ["titan's", "taint's"],
#  ["deification's", "edification's"],
#  ['details', 'dilates'],
#  ['based', 'beads'],
#  ["conrail's", "clarion's"],
#  ['relayed', 'layered'],
#  ['tors', 'rots', 'sort'],
#  ['altitudes', 'latitudes'],
#  ['carole', 'oracle'],
#  ['aloft', 'float'],
#  ['lois', 'soil', 'oils', 'silo', 'soli'],
#  ['tamps', 'stamp'],
#  ["tosca's", "coast's", "ascot's"],
#  ["aden's", "dena's", "edna's", "dane's", "dean's"],
#  ['slates', 'tassel', 'steals', 'stales'],
#  ['doe', 'ode'],
#  ["gum's", "mug's"],
#  ['raises', 'arises'],
#  ['orange', 'genaro'],
#  ['gradient', 'treading'],
#  ['breast', 'barest'],
#  ['melanin', 'lineman'],
#  ['singer', 'signer', 'resign', 'reigns', 'ingres'],
#  ['loans', 'sloan', 'salon'],
#  ['eat', 'ate', 'eta', 'tea'],
#  ["smile's", "selim's", "miles's", "slime's"],
#  ['accoutrements', 'accouterments'],
#  ['toppings', 'stopping'],
#  ['castillo', 'callisto'],
#  ['nabs', 'bans'],
#  ['sedna', 'danes', 'deans', 'andes', 'sedan', 'snead'],
#  ['flit', 'lift'],
#  ['relay', 'leary', 'early', 'layer'],
#  ['once', 'cone'],
#  ["jaunt's", "junta's"],
#  ['chisel', 'chiles'],
#  ['skit', 'kits'],
#  ['curate', 'acuter'],
#  ['ipecac', 'icecap'],
#  ["glare's", "large's", "elgar's", "lager's", "alger's"],
#  ['la', 'al'],
#  ['souped', 'pseudo'],
#  ['suitcase', 'sauciest'],
#  ["kline's", "klein's"],
#  ['riven', 'ervin'],
#  ["serial's", "israel's"],
#  ['tonier', 'orient'],
#  ['cackling', 'clacking'],
#  ["startup's", "upstart's"],
#  ['bales', 'basel', 'sable'],
#  ['snatched', 'stanched'],
#  ['ear', 'rae', 'era', 'are'],
#  ["tao's", "oat's"],
#  ["ural's", "raul's"],
#  ["ing's", "gin's"],
#  ['paths', 'staph'],
#  ['drag', 'grad'],
#  ["triage's", "gaiter's"],
#  ['how', 'who'],
#  ["amy's", "yam's", "may's"],
#  ["trippe's", "tipper's"],
#  ['detest', 'tested'],
#  ['fife', 'fief'],
#  ['sleepers', 'peerless'],
#  ['cassinos', 'caissons'],
#  ['pairs', 'parsi', 'paris'],
#  ['safer', 'fears', 'fares'],
#  ["melba's", "mable's", "mabel's", "blame's", "amble's"],
#  ['adler', 'alder'],
#  ['handcar', 'chandra'],
#  ['girt', 'grit', 'trig'],
#  ['pastes', 'spates'],
#  ['opt', 'pot', 'top'],
#  ['tarpons', 'patrons'],
#  ['caterers', 'terraces', 'retraces'],
#  ['bedlam', 'lambed', 'blamed', 'ambled'],
#  ['sirup', 'prius'],
#  ["recreant's", "terrance's"],
#  ['years', 'ayers'],
#  ['periled', 'replied'],
#  ['ratings', 'staring'],
#  ["galen's", "angle's", "angel's"],
#  ["act's", "cat's"],
#  ['sink', 'inks', 'skin'],
#  ['peppier', 'preppie'],
#  ['gina', 'agni', 'gain'],
#  ['blither', 'hilbert'],
#  ['ringside', 'residing', 'desiring'],
#  ["strait's", "artist's"],
#  ['insures', 'sunrise'],
#  ['truest', 'utters'],
#  ['trendier', 'interred'],
#  ["scat's", "acts's", "cast's"],
#  ['terran', 'errant', 'ranter'],
#  ['censers', 'screens'],
#  ["till's", "lilt's"],
#  ['transept', 'patterns'],
#  ['earthiest', 'heartiest'],
#  ['adroitly', 'idolatry', 'dilatory'],
#  ["specter's", "scepter's", "respect's"],
#  ['talent', 'latent'],
#  ['sleazier', 'realizes'],
#  ["craig's", "cigar's"],
#  ['parceled', 'replaced'],
#  ['thebes', 'behest'],
#  ['forensic', 'conifers'],
#  ['drapes', 'parsed', 'spread', 'padres', 'spared', 'rasped'],
#  ['menorahs', 'horseman'],
#  ['nations', 'anoints'],
#  ['cattily', 'tacitly'],
#  ['demurring', 'murdering'],
#  ["astor's", "sarto's", "roast's"],
#  ['weddell', 'dwelled'],
#  ['negroid', 'ignored', 'eroding', 'redoing'],
#  ['sera', 'sear', 'ares', 'eras', 'ears'],
#  ['mayors', 'morays'],
#  ['amour', 'mauro'],
#  ["cold's", "clod's"],
#  ['rousing', 'souring'],
#  ["tamra's", "marat's", "marta's"],
#  ['rereads', 'readers'],
#  ["odin's", "dion's", "dino's"],
#  ['lolcat', 'tlaloc'],
#  ['learnt', 'rental', 'antler'],
#  ['sheol', 'holes'],
#  ['oodles', 'loosed', 'soloed'],
#  ['brute', 'rebut', 'tuber'],
#  ['ogles', 'loges'],
#  ['mariadb', 'barmaid'],
#  ['ogre', 'ergo', 'roeg', 'gore'],
#  ['fora', 'afro'],
#  ['saviour', 'various'],
#  ['dora', 'road'],
#  ['beets', 'beset'],
#  ['latrines', 'entrails'],
#  ['slough', 'ghouls'],
#  ['fro', 'for'],
#  ['arms', 'mars', 'rams'],
#  ["prod's", "drop's"],
#  ['student', 'stunted'],
#  ['mired', 'rimed', 'dimer'],
#  ['marcy', 'camry'],
#  ['reality', 'irately'],
#  ['schematics', 'catechisms'],
#  ['speck', 'pecks'],
#  ['slowed', 'dowels'],
#  ["maul's", "alum's"],
#  ["gallo's", "algol's"],
#  ['root', 'oort'],
#  ['fried', 'fired'],
#  ['maroon', 'romano'],
#  ['magnate', 'magenta'],
#  ['browse', 'bowers'],
#  ['sapporo', 'apropos'],
#  ['void', 'ovid'],
#  ['keri', 'erik'],
#  ["sprite's", "stripe's", "priest's"],
#  ['hardy', 'hydra'],
#  ['spilt', 'split'],
#  ["oriental's", "relation's"],
#  ['pelts', 'slept', 'spelt'],
#  ['interim', 'termini', 'mintier'],
#  ["oscillation's", "colonialist's"],
#  ["pogo's", "goop's"],
#  ['depraved', 'pervaded'],
#  ['pones', 'epson', 'opens', 'peons'],
#  ["randell's", "darnell's"],
#  ['resort', 'sorter', 'roster', 'torres'],
#  ["garner's", "ranger's"],
#  ["lifer's", "rifle's", "flier's"],
#  ['speech', 'cheeps'],
#  ['quito', 'quoit'],
#  ['tonal', 'alton', 'talon'],
#  ['unison', 'unions'],
#  ['lister', 'liters'],
#  ['tesla', 'steal', 'slate', 'least', 'stael', 'stale', 'teals', 'tales'],
#  ['debugs', 'budges'],
#  ['repents', 'present', 'serpent'],
#  ["ismael's", "melisa's"],
#  ['skyed', 'dykes'],
#  ["warren's", "warner's"],
#  ['converge', 'congreve'],
#  ['keens', 'knees'],
#  ["elbow's", "bowel's"],
#  ['seams', 'mesas', 'sames'],
#  ['erratic', 'cartier'],
#  ['recheck', 'checker'],
#  ['upset', 'setup'],
#  ["viewer's", "review's"],
#  ['leno', 'lone', 'leon', 'noel', 'olen'],
#  ['sectors', 'corsets', 'escorts'],
#  ["bernanke's", "banneker's"],
#  ["chum's", "much's"],
#  ['heartier', 'earthier'],
#  ['sounder', 'resound'],
#  ["mores's", "morse's"],
#  ["dora's", "road's"],
#  ['threads', 'hardest', 'trashed', 'hatreds', 'dearths'],
#  ['tinned', 'indent', 'dentin', 'intend'],
#  ['bake', 'beak'],
#  ['boner', 'borne'],
#  ["lin's", "nil's"],
#  ['fauns', 'snafu'],
#  ["rapine's", "panier's", "napier's"],
#  ['agar', 'raga', 'agra'],
#  ['hobs', 'bosh'],
#  ["spat's", "past's"],
#  ["berle's", "rebel's"],
#  ['elise', 'elsie'],
#  ['demeter', 'metered'],
#  ['tokes', 'stoke'],
#  ['nieves', 'envies'],
#  ['coeds', 'codes'],
#  ['infringed', 'friending'],
#  ['scalloping', 'collapsing'],
#  ['carmella', 'marcella'],
#  ['timbres', 'timbers'],
#  ['trellis', 'stiller', 'tillers'],
#  ['keening', 'kneeing'],
#  ['chap', 'caph'],
#  ['gates', 'stage'],
#  ['tankers', 'rankest'],
#  ["kris's", "risk's"],
#  ['colones', 'console'],
#  ['mundane', 'unnamed'],
#  ['topically', 'optically'],
#  ['easter', 'teresa', 'eaters', 'teaser'],
#  ['wolfs', 'flows', 'fowls'],
#  ['liars', 'rails', 'liras', 'lairs'],
#  ['beseech', 'beeches'],
#  ['article', 'recital'],
#  ['coed', 'code'],
#  ['crimson', 'microns'],
#  ['dawns', 'wands'],
#  ['charon', 'anchor'],
#  ['puree', 'rupee'],
#  ['shad', 'dash'],
#  ["amaru's", "maura's"],
#  ['despair', 'aspired', 'diapers', 'praised'],
#  ["nassau's", "susana's"],
#  ["ruse's", "user's"],
#  ['pediatrics', 'patricides'],
#  ["armenian's", "annmarie's", "marianne's"],
#  ['goths', 'ghost'],
#  ["osman's", "mason's"],
#  ['finer', 'infer'],
#  ['cheaters', 'hectares', 'teachers'],
#  ['erasmus', 'masseur'],
#  ["solo's", "oslo's"],
#  ['replay', 'parley', 'player', 'pearly'],
#  ["ginkgo's", "gingko's"],
#  ['stickpin', 'nitpicks'],
#  ["lien's", "neil's", "nile's", "line's"],
#  ['lenore', 'lorene'],
#  ["searcher's", "research's"],
#  ['palsying', 'splaying'],
#  ['saxon', 'axons'],
#  ['chasers', 'crashes'],
#  ['saw', 'aws', 'was'],
#  ['retire', 'terrie'],
#  ['genera', 'enrage'],
#  ['polythene', 'telephony'],
#  ['wiser', 'weirs', 'wires'],
#  ['sergeants', 'estranges', 'greatness'],
#  ["dingo's", "doing's"],
#  ['orate', 'erato'],
#  ['chester', 'retches', 'etchers'],
#  ["wendi's", "edwin's"],
#  ['marrieds', 'admirers'],
#  ['need', 'eden'],
#  ['buster', 'brutes', 'rebuts', 'tubers'],
#  ['resold', 'solder'],
#  ['parroted', 'prorated', 'teardrop', 'predator'],
#  ['goop', 'pogo'],
#  ['bombing', 'mobbing'],
#  ['node', 'deon', 'done'],
#  ['twits', 'twist'],
#  ['adeline', 'aliened'],
#  ['sports', 'strops'],
#  ['wonder', 'downer'],
#  ["bristle's", "blister's"],
#  ['maura', 'amaru'],
#  ["robyn's", "bryon's", "byron's"],
#  ['sheik', 'hikes'],
#  ['pits', 'spit', 'tips'],
#  ["crooner's", "coroner's"],
#  ['spam', 'amps', 'maps'],
#  ['olga', 'goal'],
#  ['reinterpret', 'interpreter'],
#  ['caduceus', 'caucused'],
#  ["bates's", "beast's"],
#  ['harkens', 'hankers'],
#  ['calmer', 'marcel'],
#  ['fillers', 'refills'],
#  ['percale', 'replace'],
#  ['drab', 'brad', 'bard'],
#  ["senate's", "sateen's"],
#  ['enable', 'baleen'],
#  ['sander', 'snared', 'andres'],
#  ['equip', 'pique'],
#  ['film', 'milf'],
#  ["gather's", "gareth's"],
#  ['patsies', 'pasties'],
#  ['electra', 'treacle'],
#  ['spinal', 'plains'],
#  ['tins', 'nits', 'snit'],
#  ["lauri's", "luria's"],
#  ['laity', 'italy'],
#  ['sheeting', 'seething'],
#  ['cronies', 'ericson'],
#  ['elates', 'estela', 'teasel'],
#  ["leak's", "kale's", "lake's"],
#  ['smartened', 'tradesmen'],
#  ["urination's", "ruination's"],
#  ["cholera's", "chorale's"],
#  ['laze', 'zeal'],
#  ['stewart', 'swatter'],
#  ['yaws', 'ways', 'sway'],
#  ["beater's", "rebate's"],
#  ['atreus', 'seurat'],
#  ["petersen's", "pretense's"],
#  ['mechanics', 'mischance'],
#  ["wear's", "ware's"],
#  ['carbides', 'ascribed'],
#  ["parcel's", "placer's", "carpel's"],
#  ["trina's", "train's"],
#  ["rule's", "lure's"],
#  ['velma', 'melva'],
#  ['tooled', 'toledo', 'looted'],
#  ["lana's", "alan's"],
#  ['theologians', 'anthologies'],
#  ['sims', 'miss', 'isms'],
#  ['tellers', 'retells'],
#  ['grounded', 'underdog'],
#  ['angled', 'dangle', 'glenda'],
#  ['cackled', 'clacked'],
#  ['duelist', 'dilutes'],
#  ["shaw's", "wash's"],
#  ['recipes', 'precise', 'pierces'],
#  ['name', 'amen', 'mean', 'mane'],
#  ["daze's", "adze's"],
#  ["leap's", "pale's", "plea's", "peal's"],
#  ['erect', 'crete'],
#  ['mesa', 'seam', 'same'],
#  ['intrude', 'untried'],
#  ['ypres', 'preys', 'pyres'],
#  ['lapsing', 'palings', 'sapling'],
#  ['divan', 'dvina', 'viand'],
#  ['higgins', 'sighing'],
#  ["morn's", "norm's"],
#  ['stow', 'tows', 'twos'],
#  ['dire', 'ride', 'reid'],
#  ["crepe's", "creep's"],
#  ['reforests', 'foresters'],
#  ['tooling', 'looting'],
#  ['domes', 'modes', 'demos'],
#  ['bordello', 'doorbell'],
#  ["hectare's", "teacher's", "cheater's"],
#  ['distaste', 'staidest'],
#  ['norma', 'moran', 'ramon', 'manor', 'roman'],
#  ['issue', 'susie'],
#  ['theatre', 'theater'],
#  ['marbles', 'rambles'],
#  ['intenser', 'internes'],
#  ['curies', 'cruise'],
#  ['impresses', 'premisses'],
#  ["keats's", "stake's", "skate's", "steak's"],
#  ["loge's", "ogle's", "lego's"],
#  ['roomer', 'romero'],
#  ['ecru', 'cure'],
#  ['desert', 'rested', 'deters'],
#  ['lats', 'slat', 'last', 'salt'],
#  ["bus's", "sub's", "ubs's"],
#  ['alert', 'alter', 'later'],
#  ['hinges', 'neighs'],
#  ['pram', 'ramp'],
#  ['sidearms', 'misreads'],
#  ['coordinate', 'decoration'],
#  ['pearled', 'pleader'],
#  ['depend', 'pended'],
#  ['simplest', 'misspelt'],
#  ['settlers', 'trestles'],
#  ['xe', 'ex'],
#  ["bounder's", "rebound's"],
#  ['sahel', 'shale', 'heals', 'leash', 'hales'],
#  ['menials', 'seminal'],
#  ['laura', 'aural'],
#  ['dikes', 'skied'],
#  ['precipitate', 'peripatetic'],
#  ['mindless', 'mildness'],
#  ["milestone's", "limestone's"],
#  ['lab', 'alb'],
#  ['lifers', 'fliers', 'rifles'],
#  ['bangor', 'brogan'],
#  ['setters', 'testers', 'streets', 'tersest'],
#  ["lhotse's", "hostel's"],
#  ['elastics', 'scaliest', 'alcestis'],
#  ['craven', 'cavern'],
#  ['vaster', 'averts', 'starve'],
#  ['meeting', 'teeming'],
#  ["peel's", "pele's"],
#  ['sower', 'swore', 'worse'],
#  ['orgies', 'sergio'],
#  ['cat', 'act'],
#  ["won's", "now's"],
#  ['tilts', 'stilt'],
#  ['reprise', 'respire'],
#  ["least's", "steal's", "slate's", "tesla's", "stael's"],
#  ["arno's", "nora's", "aron's", "oran's", "roan's"],
#  ['orval', 'valor'],
#  ['trifling', 'flirting'],
#  ['austin', 'unitas'],
#  ['apter', 'prate', 'taper', 'petra'],
#  ['coexist', 'exotics'],
#  ["body's", "boyd's"],
#  ['halts', 'laths', 'shalt'],
#  ['lenny', 'lynne'],
#  ['drive', 'verdi', 'diver'],
#  ['tenon', 'tonne'],
#  ['rices', 'cries'],
#  ["anvil's", "alvin's"],
#  ['nerdiest', 'dniester', 'resident', 'inserted', 'trendies'],
#  ['crashing', 'chagrins'],
#  ["dunbar's", "durban's"],
#  ['macho', 'mocha'],
#  ['deep', 'peed'],
#  ["sonar's", "arson's"],
#  ['saddle', 'addles'],
#  ['dungaree', 'underage'],
#  ['item', 'emit', 'mite', 'time'],
#  ['blest', 'belts'],
#  ['lank', 'klan'],
#  ['keystone', 'keynotes'],
#  ["emo's", "moe's"],
#  ['detour', 'toured', 'routed'],
#  ['recasting', 'caterings'],
#  ['bittern', 'britten'],
#  ['stewed', 'tweeds'],
#  ['otter', 'torte'],
#  ['velours', 'louvers'],
#  ["ila's", "ali's"],
#  ["nivea's", "evian's"],
#  ['mat', 'tam'],
#  ['feints', 'infest', 'finest'],
#  ["dorian's", "inroad's"],
#  ['niggas', 'agings'],
#  ['replacing', 'parceling'],
#  ['flowed', 'wolfed', 'fowled'],
#  ['roasts', 'assort'],
#  ['tartan', 'rattan'],
#  ['daley', 'delay'],
#  ['colonialist', 'oscillation'],
#  ["aery's", "year's"],
#  ['forge', 'gofer'],
#  ['zeus', 'suez'],
#  ['earbud', 'dauber'],
#  ['costar', 'croats', 'actors', 'scrota', 'castro', 'castor'],
#  ['wonders', 'downers'],
#  ["nobel's", "noble's"],
#  ['flemish', 'himself'],
#  ["sadie's", "aside's"],
#  ['marianne', 'annmarie', 'armenian'],
#  ['compile', 'polemic'],
#  ['hustling', 'sunlight'],
#  ['sakai', 'kasai'],
#  ['ebony', 'boney'],
#  ['streaming', 'mastering', 'emigrants'],
#  ["leila's", "lelia's", "allie's"],
#  ['route', 'outer'],
#  ['wings', 'swing'],
#  ['wolves', 'vowels'],
#  ['sating', 'giants'],
#  ['able', 'abel', 'bela', 'bale', 'elba'],
#  ["girth's", "right's"],
#  ['turnover', 'overturn'],
#  ['tore', 'rote'],
#  ['empires', 'premise'],
#  ['triteness', 'interests'],
#  ["shan't", "hasn't"],
#  ['disperse', 'presides'],
#  ['sifter', 'strife', 'rifest', 'refits'],
#  ["wrap's", "warp's"],
#  ['lobe', 'bole'],
#  ['ardent', 'ranted'],
#  ["scalp's", "clasp's"],
#  ['moaned', 'daemon'],
#  ['ruble', 'bluer'],
#  ["asp's", "sap's", "spa's"],
#  ['decimate', 'medicate'],
#  ['worker', 'rework'],
#  ['lump', 'plum'],
#  ['elapses', 'pleases'],
#  ['mona', 'oman', 'moan'],
#  ["elma's", "male's", "meal's", "elam's", "lame's"],
#  ['answers', 'rawness'],
#  ['insatiable', 'banalities'],
#  ['perseid', 'preside'],
#  ["pane's", "nape's", "pena's"],
#  ["outlay's", "layout's"],
#  ['taunted', 'attuned'],
#  ['mable', 'blame', 'mabel', 'melba', 'amble'],
#  ['miters', 'merits', 'mister', 'remits', 'timers'],
#  ['many', 'myna'],
#  ['corey', 'royce', 'coyer'],
#  ['armfuls', 'armsful'],
#  ['anvils', 'silvan'],
#  ['nerves', 'severn'],
#  ['andrews', 'wardens', 'wanders'],
#  ["statement's", "testament's"],
#  ['umps', 'sump'],
#  ['conrad', 'candor', 'dacron'],
#  ['loudest', 'tousled'],
#  ["contrail's", "cilantro's"],
#  ['sallow', 'allows'],
#  ['scalene', 'cleanse'],
#  ["tran's", "rant's"],
#  ['now', 'own', 'won'],
#  ['cupola', 'copula'],
#  ["ram's", "arm's", "mar's"],
#  ["raw's", "war's"],
#  ['newt', 'went'],
#  ["incest's", "insect's"],
#  ['klein', 'liken', 'kline'],
#  ['complies', 'compiles', 'polemics'],
#  ["megaton's", "montage's", "magneto's"],
#  ['agree', 'eager'],
#  ['restarts', 'starters'],
#  ['stint', 'tints'],
#  ["saddam's", "addams's"],
#  ['taoisms', 'maoists'],
#  ["altitude's", "latitude's"],
#  ['inkling', 'kilning', 'linking'],
#  ['punters', 'punster'],
#  ["pan's", "nap's"],
#  ['rares', 'serra', 'rears'],
#  ['oars', 'rosa', 'soar'],
#  ['dot', 'tod'],
#  ['splendid', 'spindled'],
#  ["mervin's", "vermin's"],
#  ["velcro's", "clover's"],
#  ['basin', 'sabin'],
#  ["car's", "arc's", "rca's"],
#  ['maine', 'anime'],
#  ['smash', 'shams'],
#  ['stances', 'ascents'],
#  ["ante's", "etna's", "nate's"],
#  ["id's", "di's"],
#  ['files', 'flies'],
#  ["vial's", "vila's"],
#  ['developers', 'redevelops'],
#  ['hocking', 'choking'],
#  ['seabird', 'braised', 'sidebar'],
#  ['peron', 'prone'],
#  ['tritest', 'titters'],
#  ['quieter', 'requite'],
#  ['brigades', 'abridges'],
#  ['folgers', 'golfers'],
#  ['singing', 'signing'],
#  ['rival', 'viral'],
#  ['canopying', 'poignancy'],
#  ['huntsman', 'manhunts'],
#  ['stabling', 'blasting'],
#  ['mit', 'tim'],
#  ['caring', 'arcing', 'racing'],
#  ["soil's", "lois's", "silo's"],
#  ['indices', 'incised'],
#  ['lumps', 'slump', 'plums'],
#  ["lesion's", "insole's"],
#  ['mores', 'romes', 'morse'],
#  ["charisma's", "archaism's"],
#  ['proudest', 'postured', 'sprouted'],
#  ['shotguns', 'gunshots'],
#  ['alyce', 'lacey'],
#  ['ugliest', 'gluiest'],
#  ['rode', 'doer', 'oder', 'redo'],
#  ['knits', 'stink'],
#  ['toed', 'dote'],
#  ['ilks', 'silk'],
#  ['tense', 'teens'],
#  ['warehouses', 'housewares'],
#  ['rising', 'siring'],
#  ['cowers', 'escrow'],
#  ["lena's", "lane's", "lean's", "neal's"],
#  ["over's", "rove's"],
#  ['veriest', 'restive'],
#  ['si', 'is'],
#  ['albion', 'albino'],
#  ["labrador's", "larboard's"],
#  ['inclosure', 'cornelius'],
#  ['raves', 'saver', 'avers'],
#  ['cassock', 'cossack'],
#  ['dines', 'snide', 'denis'],
#  ['astir', 'stair', 'sitar'],
#  ['rhodes', 'hordes', 'horsed', 'shored'],
#  ['fortieths', 'frothiest'],
#  ['dignifies', 'signified'],
#  ["palmer's", "marple's"],
#  ['delivers', 'silvered', 'slivered'],
#  ['stare', 'taser', 'tears', 'tares', 'rates', 'aster'],
#  ['scrapes', 'parsecs'],
#  ["manual's", "alumna's"],
#  ['atolls', 'allots'],
#  ['restoring', 'resorting'],
#  ["tale's", "teal's", "leta's"],
#  ['grudging', 'drugging'],
#  ['continued', 'unnoticed'],
#  ['infests', 'fitness'],
#  ['gracie', 'cagier'],
#  ['renters', 'sterner'],
#  ["harlem's", "mahler's"],
#  ['dorset', 'sorted', 'stored', 'strode'],
#  ["tardiness's", "streisand's"],
#  ['tolyatti', 'totality'],
#  ['calks', 'lacks', 'slack'],
#  ['leif', 'life', 'lief', 'file'],
#  ['logarithms', 'algorithms'],
#  ['sombrely', 'somberly'],
#  ["moray's", "mayor's"],
#  ['smarter', 'armrest'],
#  ['retweets', 'tweeters'],
#  ["sorbet's", "osbert's", "strobe's"],
#  ["nit's", "tin's", "isn't"],
#  ["eden's", "need's"],
#  ['voided', 'devoid'],
#  ['concerting', 'concreting'],
#  ['fondus', 'founds'],
#  ['initiated', 'dietitian'],
#  ['redhead', 'adhered'],
#  ['loop', 'pool', 'polo'],
#  ['shook', 'hooks'],
#  ['novels', 'sloven'],
#  ["plane's", "panel's", "nepal's"],
#  ["diver's", "verdi's", "drive's"],
#  ['prince', 'pincer'],
#  ["proteus's", "posture's"],
#  ["atria's", "atari's", "tiara's"],
#  ["kristen's", "stinker's", "kirsten's"],
#  ['peek', 'keep'],
#  ['riel', 'rile', 'lire'],
#  ['sheba', 'hbase'],
#  ['ella', 'lela'],
#  ['certifications', 'rectifications'],
#  ['orientating', 'integration'],
#  ['nomad', 'damon'],
#  ["heron's", "horne's", "rhone's"],
#  ['burl', 'blur'],
#  ['stead', 'sated', 'dates'],
#  ['girts', 'grits', 'grist'],
#  ['puns', 'spun'],
#  ['incest', 'nicest', 'insect'],
#  ["soto's", "soot's"],
#  ['caliper', 'replica'],
#  ['nested', 'tensed'],
#  ['star', 'arts', 'tsar', 'tars', 'rats'],
#  ['stoker', 'stroke'],
#  ['decals', 'scaled'],
#  ['potions', 'options'],
#  ["lorre's", "errol's"],
#  ['ticks', 'stick'],
#  ['regina', 'regain'],
#  ['pasteur', 'pasture'],
#  ['printings', 'sprinting'],
#  ['pinking', 'kingpin'],
#  ['demoniac', 'comedian'],
#  ['altair', 'lariat'],
#  ["argon's", "groan's", "organ's"],
#  ["singer's", "signer's", "ingres's"],
#  ['toiler', 'loiter'],
#  ["resident's", "dniester's"],
#  ["anime's", "maine's"],
#  ['despot', 'posted', 'depots'],
#  ['york', 'kory'],
#  ['wormwood', 'woodworm'],
#  ["verna's", "raven's"],
#  ['dingy', 'dying'],
#  ["irtish's", "tishri's"],
#  ['bidet', 'debit'],
#  ['resumption', 'importunes'],
#  ['masher', 'harems'],
#  ['nosed', 'nodes'],
#  ['canter', 'recant', 'nectar', 'trance', 'cretan'],
#  ['satanism', 'mantissa'],
#  ['martel', 'armlet'],
#  ['stabled', 'blasted', 'baldest'],
#  ['manuela', 'alumnae'],
#  ["romance's", "cameron's"],
#  ['peters', 'pester', 'preset'],
#  ["gardenia's", "drainage's"],
#  ['demotion', 'motioned'],
#  ['bushels', 'blushes'],
#  ['prigs', 'sprig', 'grips'],
#  ["alden's", "nelda's"],
#  ['usurpers', 'pursuers'],
#  ["pest's", "step's"],
#  ['alcindor', 'ironclad'],
#  ['titling', 'tlingit', 'tilting'],
#  ['turnovers', 'overturns'],
#  ['melded', 'meddle'],
#  ['corps', 'crops'],
#  ['reorgs', 'rogers'],
#  ['mercado', 'caromed', 'comrade'],
#  ['indenting', 'intending'],
#  ['sledging', 'geldings'],
#  ["nepali's", "alpine's"],
#  ["aisle's", "elias's", "elisa's"],
#  ['cinema', 'anemic'],
#  ['producer', 'procured'],
#  ['sliver', 'silver', 'livers'],
#  ['olsen', 'noels'],
#  ["kate's", "teak's", "take's"],
#  ["ella's", "lela's"],
#  ["elnora's", "lenora's", "elanor's", "loaner's", "lorena's"],
#  ['linkage', 'leaking'],
#  ['daniel', 'nailed', 'alined', 'denial'],
#  ['brawlers', 'warblers'],
#  ['tautest', 'statute'],
#  ['wired', 'weird', 'wider'],
#  ['noelle', 'leonel'],
#  ['meagan', 'manage'],
#  ["lewis's", "wiles's"],
#  ['flier', 'rifle', 'lifer'],
#  ['flees', 'feels'],
#  ['singers', 'signers', 'resigns', 'ingress'],
#  ['yemen', 'enemy'],
#  ['ankhs', 'shank', 'khans', 'hanks'],
#  ['robing', 'boring'],
#  ['earliest', 'ateliers'],
#  ['hates', 'heats', 'haste'],
#  ['seedier', 'desiree'],
#  ['disks', 'skids'],
#  ['supers', 'purses'],
#  ['tutsi', 'titus'],
#  ['stile', 'tiles', 'islet'],
#  ['overdose', 'overdoes'],
#  ['emanates', 'manatees'],
#  ['shouts', 'souths'],
#  ['logan', 'anglo', 'golan', 'along'],
#  ['feeling', 'fleeing'],
#  ['plugins', 'pulsing'],
#  ['sidney', 'disney'],
#  ['lattice', 'tactile'],
#  ['plaint', 'pliant'],
#  ['dallies', 'sallied'],
#  ['remake', 'kareem'],
#  ['staples', 'pastels'],
#  ['redis', 'rides', 'sired', 'dries'],
#  ['thing', 'night'],
#  ["bosnia's", "bonsai's"],
#  ['crochets', 'crotches'],
#  ['archie', 'achier'],
#  ["rethink's", "thinker's"],
#  ['enters', 'sterne', 'tenser', 'ernest', 'resent'],
#  ['transient', 'intranets'],
#  ['barley', 'bleary', 'barely'],
#  ['deform', 'formed'],
#  ["nigga's", "aging's"],
#  ["pinto's", "piton's", "point's"],
#  ["bangle's", "bengal's"],
#  ['rotates', 'rosetta', 'toaster'],
#  ['ac', 'ca'],
#  ['islams', 'missal'],
#  ['belgian', 'bengali', 'algenib'],
#  ['enfolds', 'fondles'],
#  ["prattle's", "platter's"],
#  ['hits', 'shit', 'this'],
#  ['flared', 'alfred'],
#  ["fern's", "nerf's"],
#  ['lots', 'slot', 'lost'],
#  ['slides', 'sidles'],
#  ['thor', 'roth'],
#  ["ubangi's", "bangui's"],
#  ['swearer', 'wearers'],
#  ["thermos's", "smother's"],
#  ["emusic's", "cesium's", "miscue's"],
#  ['ales', 'elsa', 'lesa', 'leas', 'sale', 'seal'],
#  ["cedar's", "cadre's"],
#  ["shaka's", "sakha's"],
#  ['grater', 'garret', 'garter'],
#  ['mel', 'elm'],
#  ['delights', 'slighted'],
#  ['boer', 'bore', 'ebro', 'robe'],
#  ['configures', 'refocusing'],
#  ["pasty's", "patsy's"],
#  ['nashua', 'shauna'],
#  ["tonga's", "tango's"],
#  ['spate', 'paste', 'tapes', 'pates', 'septa'],
#  ["okra's", "karo's"],
#  ['touts', 'stout'],
#  ['devise', 'sieved'],
#  ['rapiers', 'repairs', 'raspier', 'parries'],
#  ['arline', 'linear'],
#  ["marciano's", "macaroni's"],
#  ["stoner's", "nestor's", "sterno's"],
#  ['repeals', 'relapse'],
#  ["sprout's", "stupor's", "proust's"],
#  ['grease', 'agrees'],
#  ['deposit', 'posited', 'topside', 'dopiest'],
#  ['bengal', 'bangle'],
#  ["team's", "meat's", "mate's"],
#  ['acrostic', 'socratic'],
#  ['overacts', 'overcast'],
#  ["canto's", "acton's"],
#  ['sourest', 'ousters'],
#  ['inonu', 'union'],
#  ['fended', 'defend'],
#  ['mailed', 'medial', 'imelda'],
#  ['brno', 'born'],
#  ['secretion', 'erections'],
#  ['lake', 'kale', 'leak'],
#  ['gaps', 'gasp'],
#  ["lima's", "mail's", "mali's"],
#  ["awl's", "law's"],
#  ['gallo', 'algol'],
#  ['vessel', 'selves'],
#  ['shear', 'rheas', 'hares', 'share', 'hears'],
#  ['nemesis', 'siemens'],
#  ["salon's", "sloan's"],
#  ["caisson's", "cassino's"],
#  ['stupor', 'sprout', 'proust'],
#  ['imams', 'maims'],
#  ['sprayer', 'prayers'],
#  ['predominates', 'impersonated'],
#  ['putin', 'input'],
#  ['oval', 'olav'],
#  ['tweeter', 'retweet'],
#  ['lin', 'nil'],
#  ['whale', 'wheal'],
#  ['sellouts', 'outsells'],
#  ["brno's", "born's"],
#  ['reveling', 'levering'],
#  ['gurgles', 'slugger'],
#  ['breath', 'bertha', 'bather'],
#  ['sub', 'ubs', 'bus'],
#  ['rape', 'pare', 'pear', 'earp', 'reap'],
#  ['bast', 'bats', 'stab', 'tabs'],
#  ['rinse', 'risen', 'reins', 'siren', 'resin'],
#  ['drooled', 'doodler'],
#  ['hassles', 'slashes'],
#  ["player's", "parley's", "replay's"],
#  ['flesh', 'shelf'],
#  ['envied', 'veined', 'endive'],
#  ['undated', 'daunted'],
#  ['plead', 'pedal', 'paled'],
#  ['uterus', 'suture'],
#  ['field', 'fidel', 'filed', 'flied'],
#  ['carlo', 'coral', 'carol'],
#  ['manley', 'laymen', 'meanly', 'namely'],
#  ["alba's", "baal's"],
#  ["timer's", "miter's", "merit's"],
#  ['cleaners', 'cleanser'],
#  ['tyros', 'troys', 'story'],
#  ['snatch', 'stanch', 'chants'],
#  ['glossing', 'goslings'],
#  ['boast', 'boats'],
#  ['deal', 'dale', 'lade', 'lead', 'leda'],
#  ['lacking', 'calking'],
#  ['porter', 'report'],
#  ['here', 'rhee'],
#  ['costing', 'gnostic'],
#  ['open', 'nope', 'peon', 'pone'],
#  ["so's", "os's"],
#  ['theresa', 'reheats', 'heaters'],
#  ['missile', 'similes'],
#  ['dirge', 'ridge'],
#  ["martel's", "armlet's"],
#  ['urinals', 'insular'],
#  ['flea', 'leaf'],
#  ["slut's", "lust's"],
#  ['stonier', 'orients'],
#  ['starch', 'charts'],
#  ['misprint', 'imprints'],
#  ['skirting', 'striking'],
#  ['shaw', 'haws', 'wash'],
#  ['neruda', 'unread'],
#  ['selection', 'elections'],
#  ['gape', 'page'],
#  ['blogs', 'globs'],
#  ['samson', 'masons'],
#  ['alba', 'baal'],
#  ['laden', 'alden', 'nelda'],
#  ['dales', 'leads', 'lades', 'deals'],
#  ['sat', 'ats'],
#  ['shower', 'whores'],
#  ['tracer', 'carter', 'crater'],
#  ['colonialists', 'oscillations'],
#  ['lime', 'emil', 'mile'],
#  ['purims', 'purism'],
#  ["wriggle's", "wiggler's"],
#  ["abode's", "adobe's"],
#  ['arc', 'rca', 'car'],
#  ['ashore', 'hoarse'],
#  ["suture's", "uterus's"],
#  ['sued', 'used', 'duse', 'dues'],
#  ["venetian's", "aventine's"],
#  ['crooner', 'coroner'],
#  ...]

# %% [markdown]
# *Data Structures and Information Retrieval in Python*
#
# Copyright 2021 Allen Downey
#
# License: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
